# %% [markdown]
# ### Preparación de archivos y procesamiento de datos

# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
import string
from nltk.corpus import stopwords

# %%
data_items = pd.read_csv('BX_Books.csv', sep=';', error_bad_lines=False, encoding='latin-1')
data = pd.read_csv('BX-Book-Ratings.csv', sep=';', error_bad_lines=False, encoding='latin-1')

# %%
data.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
data_items.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author  Year-Of-Publication                Publisher  \
# 0    Mark P. O. Morford                 2002  Oxford University Press
# 1  Richard Bruce Wright                 2001    HarperFlamingo Canada
# 2          Carlo D'Este                 1991          HarperPerennial
# 3      Gina Bari Kolata                 1999     Farrar Straus Giroux
# 4       E. J. W. Barber                 1999   W. W. Norton & Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
books_data = data_items.drop(['Year-Of-Publication','Image-URL-S','Image-URL-M','Image-URL-L'],axis=1)
ratings = books_data.merge(data,on='ISBN')

# %%
number_of_ratings = ratings.groupby('ISBN')['Book-Rating'].count().reset_index()
number_of_ratings.rename(columns={'Book-Rating':'Number of Book-Rating'}, inplace=True)
ratings = ratings.merge(number_of_ratings,on='ISBN')

# %%
ratings = ratings[ratings['Number of Book-Rating'] >= 30]
ratings.shape
# Out:
# (315065, 7)

# %%
ratings.drop_duplicates(['User-ID', 'Book-Title'], inplace=True)

# %%
ratings.shape
# Out:
# (313546, 7)

# %%
book_pivot=ratings.pivot_table(columns='User-ID',index='Book-Title',values='Book-Rating')
book_pivot.fillna(0, inplace=True)
book_pivot
# Out:
# User-ID                                             8       9       10      \
# Book-Title
# 'Salem's Lot                                           0.0     0.0     0.0
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# User-ID                                             14      16      17      \
# Book-Title
# 'Salem's Lot                                           0.0     0.0     0.0
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# User-ID                                             26      32      39      \
# Book-Title
# 'Salem's Lot                                           0.0     0.0     0.0
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# User-ID                                             42      ...  278831  \
# Book-Title                                                  ...
# 'Salem's Lot                                           0.0  ...     0.0
# 10 Lb. Penalty                                         0.0  ...     0.0
# 16 Lighthouse Road                                     0.0  ...     0.0
# 1984                                                   0.0  ...     0.0
# 1st to Die: A Novel                                    0.0  ...     0.0
# ...                                                    ...  ...     ...
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0  ...     0.0
# e                                                      0.0  ...     0.0
# stardust                                               0.0  ...     0.0
#
# User-ID                                             278832  278836  278838  \
# Book-Title
# 'Salem's Lot                                           0.0     0.0     0.0
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# User-ID                                             278843  278844  278846  \
# Book-Title
# 'Salem's Lot                                           0.0     0.0     0.0
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# User-ID                                             278849  278851  278854
# Book-Title
# 'Salem's Lot                                           0.0     0.0     0.0
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# [3859 rows x 50086 columns]

# %%
book_sparse=csr_matrix(book_pivot)

# %% [markdown]
# ### Modelo KNN

# %%
from sklearn.neighbors import NearestNeighbors
k = 10
model=NearestNeighbors(n_neighbors=k,algorithm='brute')
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute', n_neighbors=10)

# %%
distances,suggestions=model.kneighbors(book_pivot.iloc[253,:].values.reshape(1,-1))

# %%
distances
# Out:
# array([[ 0.        , 34.2636834 , 34.7706773 , 35.42597917, 35.58089375,
#         35.60898763, 36.26292873, 36.31803959, 36.33180425, 36.35931793]])

# %%
suggestions
# Out:
# array([[ 253, 3541, 1180, 2622, 1181, 2845, 3196, 1369, 2333,  637]],
#       dtype=int64)

# %%
for i in range(len(suggestions)):
    print(book_pivot.index[suggestions[i]])
# Out:
# Index(['Angle of Repose (Contemporary American Fiction)', 'Thornyhold',
#        'Golden Cup', 'Tall, Dark, and Deadly', 'Golden Orange',
#        'The Curse of the Mummy's Tomb (Goosebumps, No 5)', 'The Midnight Hour',
#        'Icon', 'Second Wind', 'Commitments'],
#       dtype='object', name='Book-Title')

# %%
def reco(book_name):
    book_id=np.where(book_pivot.index==book_name)[0][0]
    distances,suggestions=model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1))
    
    for i in range(len(suggestions)):
        if i==0:
            print("the suggestions are ",book_name,"are : ")
        if not i:
            print(book_pivot.index[suggestions[i]])

# %%
reco('Jurassic Park')
# Out:
# the suggestions are  Jurassic Park are :
# Index(['Jurassic Park', 'McNally's Caper (Archy McNally Novels (Paperback))',
#        'GEMINI CONTENDERS', 'Night Mare #06', 'After Dark', 'Golden Cup',
#        'Fatal Terrain', 'Night of the Living Dummy (Goosebumps, No 7)',
#        'Women in His Life', 'The Satanic Verses'],
#       dtype='object', name='Book-Title')

# %%
reco("Harry Potter and the Sorcerer's Stone (Book 1)")
# Out:
# the suggestions are  Harry Potter and the Sorcerer's Stone (Book 1) are :
# Index(['Harry Potter and the Sorcerer's Stone (Book 1)', 'Falling Backwards',
#        'Golden Cup', 'Fatal Terrain',
#        'Attack of the Mutant (Goosebumps, No 25)', 'The Invitation',
#        'McNally's Caper (Archy McNally Novels (Paperback))',
#        'GEMINI CONTENDERS', 'Hidden Leaves (Debeers)',
#        'The Mystery of the Cupboard (Indian in the Cupboard)'],
#       dtype='object', name='Book-Title')

# %%
reco('The Two Towers (The Lord of the Rings, Part 2)')
# Out:
# the suggestions are  The Two Towers (The Lord of the Rings, Part 2) are :
# Index(['The Two Towers (The Lord of the Rings, Part 2)',
#        'The Return of the King (The Lord of the Rings, Part 3)', 'Golden Cup',
#        'Tall, Dark, and Deadly', 'Golden Orange',
#        'The Curse of the Mummy's Tomb (Goosebumps, No 5)', 'Thornyhold',
#        'The Satanic Verses', 'Snagged', 'The Midnight Hour'],
#       dtype='object', name='Book-Title')

# %%
def recoForInteface(book_name):
  book_id=np.where(book_pivot.index==book_name)[0][0]
  distances,suggestions=model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1))
  #result = ""
  #result += "the suggestions for "+book_name+" are:"
  result = []
  for i in range(len(suggestions)):
    #if i==0:
    #  result += "the suggestions for "+book_name+" are:"
    #if not i:
    result.append(book_pivot.index[suggestions[i]])
  return result[0].tolist()

# %%
recoForInteface('Jurassic Park')
# Out:
# ['Jurassic Park',
#  "McNally's Caper (Archy McNally Novels (Paperback))",
#  'GEMINI CONTENDERS',
#  'Night Mare #06',
#  'After Dark',
#  'Golden Cup',
#  'Fatal Terrain',
#  'Night of the Living Dummy (Goosebumps, No 7)',
#  'Women in His Life',
#  'The Satanic Verses']

# %%
x = recoForInteface('Jurassic Park')
type(x)
len(x)
# Out:
# 10

# %%
listaDeTitulos = list(set(ratings["Book-Title"]))
listaDeTitulos
# Out:
# ['Jane Eyre (Bantam Classics)',
#  'Trunk Music (Detective Harry Bosch Mysteries)',
#  'Cujo',
#  'Rose Madder',
#  'One Door Away from Heaven',
#  "Hidden Agendas (Tom Clancy's Net Force, No. 2)",
#  'Name of the Rose-Nla',
#  "Freedom's Landing",
#  'HEARTBURN',
#  'Pastime',
#  'The Music of Dolphins (Apple Signature Edition)',
#  'The Darwin Awards II: Unnatural Selection',
#  'Killing Dance (Anita Blake Vampire Hunter (Paperback))',
#  'Death du Jour',
#  'Dog Handling',
#  "The Ultimate Hitchhiker's Guide",
#  "Open House (Oprah's Book Club (Paperback))",
#  'The Harbor',
#  'The Teeth of the Tiger',
#  'A Night in Terror Tower (Goosebumps, No 27)',
#  'Wish You Were Here (Mrs. Murphy Mysteries (Paperback))',
#  'The Scandalous Summer of Sissy LeBlanc : A Novel',
#  'I Am Legend',
#  'The Vision',
#  'Wild Mountain Thyme',
#  'Sideways Stories from Wayside School (Wayside School)',
#  'Mad Jack',
#  'Object Lessons',
#  'A Walk in the Woods: Rediscovering America on the Appalachian Trail (Official Guides to the Appalachian Trail)',
#  'Safe Harbor',
#  'Cavedweller',
#  "Left Behind: A Novel of the Earth's Last Days (Left Behind #1)",
#  'The Dark Half',
#  'Till We Meet Again',
#  'GREAT GATSBY (REISSUE)',
#  'Second Nature',
#  'A Case of Need',
#  'Border Music',
#  'All Things Wise and Wonderful',
#  'Vital Signs',
#  'Murder on the Iditarod Trail (Alaska Mysteries (Paperback))',
#  'Holding the Dream (Dream Trilogy)',
#  'Surfacing',
#  'Daisy Fay and the Miracle Man',
#  "Driving Mr. Albert: A Trip Across America With Einstein's Brain",
#  'Call of The Wild, White Fang (Bantam Classics)',
#  'White Noise (Contemporary American Fiction)',
#  'The Fourth Estate',
#  'The Ersatz Elevator (A Series of Unfortunate Events, Book 6)',
#  'My Dream of You',
#  'The Holiday Present',
#  'Rainbow Six',
#  "The World According to Garp (Ballantine Reader's Circle)",
#  'Mistress',
#  'Sacred Clowns (Joe Leaphorn/Jim Chee Novels)',
#  'Blackberry Wine',
#  'Diary of a Mad Bride (Summer Display Opportunity)',
#  'Tulip Fever',
#  'Sleep No More',
#  'A Confederacy of Dunces (Evergreen Book)',
#  'Home for the Holidays',
#  'Candide (Penguin Classics)',
#  'Zoya',
#  'The Blessing Way (Joe Leaphorn Novels)',
#  'Maggie Needs an Alibi',
#  'The Perks of Being a Wallflower',
#  'Move to Strike',
#  'The Invasion (Animorphs, No 1)',
#  "Larry's Party",
#  'Sister of My Heart',
#  "Rachel's Holiday",
#  'Macgregor Brides (Macgregors)',
#  'Halfway To Heaven',
#  'Blind Faith',
#  'Heart of Darkness (Dover Thrift Editions)',
#  'The House on Mango Street (Vintage Contemporaries)',
#  "The Devil's Arithmetic",
#  "Lucifer's Hammer",
#  'The Cat Who Saw Stars (Cat Who... (Paperback))',
#  'Under the Banner of Heaven : A Story of Violent Faith',
#  'Jack & Jill (Alex Cross Novels)',
#  'Der Alchimist.',
#  'Sisterhood of the Traveling Pants',
#  'Murder on the Potomac (Capital Crime Mysteries)',
#  'Leaving Cold Sassy: The Unfinished Sequel to Cold Sassy',
#  'Charade',
#  'The Cat Who Saw Stars',
#  'Hunting Season (Anna Pigeon Novels (Paperback))',
#  'K-Pax',
#  'F Is for Fugitive (Kinsey Millhone Mysteries (Paperback))',
#  'Homeport',
#  'Up Country',
#  "The Sweet Potato Queens' Big-Ass Cookbook (and Financial Planner)",
#  'Fried Green Tomatoes at the Whistle Stop Cafe',
#  "The Bride's Rescuer",
#  'Traveling Mercies: Some Thoughts on Faith',
#  'H Is for Homicide (Kinsey Millhone Mysteries (Paperback))',
#  'Navy Wife (Silhouette Romance)',
#  'Gathering Blue (Readers Circle)',
#  'Does My Bum Look Big in This?',
#  'Deep Midnight',
#  'Prince Caspian',
#  'Microserfs',
#  'A Simple Plan',
#  'The Cat Who Played Brahms',
#  'The Lone Ranger and Tonto Fistfight in Heaven',
#  'Congo',
#  "Magic's Pawn (The Last Herald-Mage Series, Book 1)",
#  'Lost in Translation',
#  'Sliver: A Novel',
#  'Disgrace',
#  'Over the Edge',
#  'Complicity',
#  'stardust',
#  'Sphere',
#  'Egg Monsters from Mars (Goosebumps, No 42)',
#  'The Cat Who Sang for the Birds (Cat Who... (Paperback))',
#  'A Suitable Vengeance',
#  'The Return',
#  "Smilla's Sense of Snow",
#  "Live and Learn and Pass It on: People Ages 5 to 95 Share What They'Ve Discovered About Life, Love, and Other Good Stuff (Live & Learn & Pass It on)",
#  '3001: The Final Odyssey',
#  'Hawaii',
#  'The Blue Day Book',
#  'The Edge of Town',
#  "Tom Clancy's Op-Center: Divide and Conquer (Tom Clancy's Op Center (Paperback))",
#  'Bitter Harvest',
#  'Sex and the City',
#  'Ladder of Years',
#  'The Indian in the Cupboard (rack) (Indian in the Cupboard)',
#  "A Greek God at the Ladies' Club (Avon Romance)",
#  'True Betrayals',
#  'The Girl Who Cried Monster (Goosebumps, No 8)',
#  'Eclipse Bay',
#  'The Stand (The Complete and Uncut Edition)',
#  "Je Voudrais Que Quelqu'un M'Attende Quelque Part",
#  'Stealing Shadows (Shadows Trilogy (Paperback))',
#  'Realm of Shadows',
#  'Hollywood Wives - The New Generation',
#  'The More I See You',
#  'The Grass Is Always Greener Over the Septic Tank',
#  'Harry Potter and the Goblet of Fire (Book 4)',
#  "Joy School (Ballantine Reader's Circle)",
#  'Veronika Decides to Die',
#  'Bluebeard',
#  "Fortune's Rocks : A Novel",
#  'Tough Cookie',
#  'Big Fish',
#  'Eden Close',
#  'Anne of Ingleside (Anne of Green Gables Novels (Paperback))',
#  'Lord of the Silent: A Novel of Suspense',
#  'Farewell to Manzanar: A True Story of Japanese American Experience During and  After the World War II Internment',
#  'Adventures of Huckleberry Finn (Dover Thrift Editions)',
#  'K Is for Killer (Grafton, Sue. Kinsey Millhone Mysteries.)',
#  'Stranger in a Strange Land (Remembering Tomorrow)',
#  'No One to Trust',
#  'In the Presence of Enemies',
#  'The First Victim',
#  'The Cabinet of Curiosities',
#  'Flowers for Algernon (Bantam Classic)',
#  'The Tailor of Panama',
#  'Emily of New Moon',
#  'Watermelon',
#  'The Other Side of Midnight',
#  'A Passage to India',
#  "The Magician's Nephew (rack) (Narnia)",
#  'Dating Without Novocaine (Red Dress Ink)',
#  'Anne of Windy Poplars (Anne of Green Gables Novels (Paperback))',
#  'People of the River (The First North Americans series, Book 4)',
#  'The Anastasia Syndrome',
#  'When the Bough Breaks (Alex Delaware Novels (Paperback))',
#  "Fortune's Hand",
#  "Fall on Your Knees (Oprah's Book Club)",
#  'The Mulberry Tree',
#  'Rebellion',
#  'Middle of Nowhere',
#  "Hanna's Daughters (Ballantine Reader's Circle)",
#  'Jemima J',
#  'Triggerfish Twist',
#  'The Experiment',
#  'Dreaming in Cuban',
#  'Rising Tides',
#  'September',
#  'Talk Before Sleep: A Novel',
#  'The Taking (Koontz, Dean)',
#  'The Beach',
#  'A Cold Heart: An Alex Delaware Novel',
#  'The Forest',
#  'The Cat Who Went to Heaven',
#  'Follow the River',
#  'Sex & the City',
#  'The Eternity Code (Artemis Fowl, Book 3)',
#  'The Haunted Mask (Goosebumps, No 11)',
#  'Balzac and the Little Chinese Seamstress : A Novel',
#  'Another City, Not My Own: A Novel in the Form of a Memoir',
#  'Intensity',
#  'Hidden Riches',
#  'Nimitz Class',
#  'Fourth Procedure',
#  'The Trials of Tiffany Trott',
#  'Whirlwind (Tyler, Book 1)',
#  'Wide Sargasso Sea (Norton Paperback Fiction)',
#  'The Dante Club : A Novel',
#  'Hellfire',
#  'Hello Darling, Are You Working?',
#  'The Mother Tongue',
#  'Best Kept Secrets',
#  'Pigs in Heaven',
#  'Die SÃ?Â¤ulen der Erde. Roman.',
#  'The Hunt for Red October',
#  'The Virgin Blue',
#  'River, Cross My Heart : A Novel',
#  'Darkfall',
#  'Ishmael: An Adventure of the Mind and Spirit',
#  'Fault Lines',
#  'Midnight Champagne : A Novel (Mysteries & Horror)',
#  'The New York Trilogy: City of Glass, Ghosts, the Locked Room (Contemporary American Fiction Series)',
#  'Jitterbug Perfume',
#  'The Ghost',
#  'Here on Earth',
#  'The Conspiracy Club',
#  "If I'd Killed Him When I Met Him (Elizabeth MacPherson Novels (Paperback))",
#  'No Safe Place',
#  "Don't Let's Go to the Dogs Tonight : An African Childhood",
#  'Dances With Wolves',
#  'Crime Brulee (Culinary Mysteries (Paperback))',
#  'The Celestine Prophecy (Celestine Prophecy)',
#  'Stupid White Men ...and Other Sorry Excuses for the State of the Nation!',
#  'The Beast from the East (Goosebumps, No 43)',
#  'La Sombra Del Viento/The Shadow Of The Wind',
#  'The Witch of Blackbird Pond (Yearling Newbery)',
#  'Love in the Time of Cholera',
#  'Getting Over Jack Wagner',
#  "Lucky's Lady",
#  "Dr. Atkins' New Diet Revolution",
#  'Bell Jar',
#  'The Gunslinger (The Dark Tower, Book 1)',
#  'People of Darkness (Jim Chee Novels)',
#  'Spring Fancy',
#  "He Sees You When You're Sleeping : A Novel",
#  "Operating Instructions: A Journal of My Son's First Year",
#  'A Wrinkle In Time',
#  'Once in a Lifetime',
#  "The Soul Catcher: A Maggie O'Dell Novel",
#  "Before Women Had Wings (Ballantine Reader's Circle)",
#  'Orchid Blues (Holly Barker Novels (Paperback))',
#  'Family Honor',
#  'SHAMPOO PLANET : SHAMPOO PLANET',
#  'Amazonia',
#  'Seven Habits Of Highly Effective People',
#  'GEMINI CONTENDERS',
#  'Cry Wolf',
#  'Picture of Dorian Gray',
#  'Das Superwieb',
#  'Temple',
#  'Taltos: Lives of the Mayfair Witches',
#  'Critical Conditions',
#  'Iced',
#  'Unless : A Novel',
#  'Playing for the Ashes',
#  'An American Childhood',
#  'Saucer',
#  'The Miserable Mill (A Series of Unfortunate Events, Book 4)',
#  "The Other Side and Back: A Psychic's Guide to Our World and Beyond",
#  'Captain Underpants and the Perilous Plot of Professor Poopypants: The Fourth Epic Novel (Captain Underpants (Paperback))',
#  'Exclusive',
#  "The Devil's Code",
#  'The Last Chance Cafe : A Novel',
#  "Cordina'S Royal Family",
#  'Message in a Bottle',
#  'Moment of Truth',
#  'The Plague Tales',
#  'SHIPPING NEWS',
#  'The Red Badge of Courage (Bantam Classics)',
#  'Saint Maybe',
#  'The Prayer of Jabez: Breaking Through to the Blessed Life',
#  'One Hundred Years of Solitude',
#  'Miss Julia Speaks Her Mind : A Novel',
#  'Strapless (Red Dress Ink (Paperback))',
#  'The Vendetta Defense',
#  'The Pillars of Creation (Sword of Truth, Book 7)',
#  'Like Water for Chocolate: A Novel in Monthly Installments With Recipes, Romances and Home Remedies',
#  'Daughter of Fortune: A Novel',
#  "Cry, the Beloved Country (Oprah's Book Club)",
#  'The Regulators',
#  'Sanctuary',
#  'Miss Julia Takes over',
#  'Once a Thief',
#  'Lola Carlyle Reveals All (Avon Light Contemporary Romances)',
#  "The Lake of Dead Languages (Ballantine Reader's Circle)",
#  'Fear and Loathing in Las Vegas : A Savage Journey to the Heart of the American Dream',
#  'To Cut a Long Story Short',
#  'Dead Man Walking: An Eyewitness Account of the Death Penalty in the United States',
#  'Care of the Soul : A Guide for Cultivating Depth and Sacredness in Everyday Life',
#  'The Last Time They Met : A Novel',
#  'Summer of Storms',
#  'Les Miserables a New Unabridged Translation (Signet Classics)',
#  'Atlantis Found (Dirk Pitt Adventures (Hardcover))',
#  'The Pelican Brief',
#  'A Fine Balance',
#  'Mere Christianity: A revised and enlarged edition, with a new introduction, of the three books, The case for Christianity, Christian behaviour, and Beyond personality',
#  'The Kiss',
#  'The Woman Next Door',
#  'Bygones',
#  'Pelican Brief',
#  'The Lady and the Unicorn',
#  "Dude, Where's My Country?",
#  'The First Eagle (Jim Chee Novels)',
#  'A 4th Course of Chicken Soup for the Soul: 101 More Stories to Open the Heart and Rekindle the Spirit',
#  'Doomsday Book',
#  'Mindbend',
#  'To Play the Fool',
#  'Tales from Watership Down',
#  'The Short Forever',
#  'The Coffin Dancer (Lincoln Rhyme Novels (Paperback))',
#  'Farm Fatale: A Comedy of Country Manors',
#  'THREE TO GET DEADLY : A Stephanie Plum Novel',
#  'The First Deadly Sin',
#  'Omerta',
#  'Private Screening',
#  'Secrets of the Morning (Cutler)',
#  "Boone's Lick : A Novel",
#  'The Wide Window (A Series of Unfortunate Events, Book 3)',
#  'Pattern Recognition',
#  'Undead and Unwed (Berkley Sensation)',
#  'The Dark Highlander',
#  'Durable Goods',
#  'Divine Secrets of the Ya-Ya Sisterhood : A Novel',
#  'The Bridge Across Forever',
#  'The Bell Jar : A Novel (Perennial Classics)',
#  'Simisola',
#  'Funeral in Blue',
#  'When Rabbit Howls',
#  'The End Of The Dream The Golden Boy Who Never Grew Up : Ann Rules Crime Files Volume 5',
#  'While I Was Gone',
#  'How to Eat Fried Worms',
#  'Impetuous Innocent',
#  'Book Club',
#  "Alice's Adventures in Wonderland and Through the Looking Glass",
#  'Memnoch the Devil : The Vampire Chronicles (Vampire Chronicles)',
#  'Once Upon a Kiss',
#  'Irish Hearts',
#  'Harry Potter and the Chamber of Secrets Postcard Book',
#  'Murder at the FBI (Capital Crime Mysteries)',
#  'The Fly on the Wall',
#  'To the Nines: A Stephanie Plum Novel',
#  'The Killing Kind',
#  'Herr Lehmann.',
#  'YESTERDAY, I CRIED : Celebrating the Lessons of Living and Loving',
#  'Fit for Life',
#  'Chicken Soup for the College Soul : Inspiring and Humorous Stories for College Students (Chicken Soup for the Soul)',
#  'Ground Zero and Beyond',
#  'The Curious Incident of the Dog in the Night-Time : A Novel',
#  'Cold Mountain (MTI) (Vintage Contemporaries)',
#  'Inca Gold (Clive Cussler)',
#  'Booked to Die (Cliff Janeway Novels (Paperback))',
#  'Practical Demonkeeping',
#  'Stanislaski Brothers (Silhouette Promo)',
#  'The Grilling Season',
#  'Pagan Babies',
#  'Homeland and Other Stories',
#  'The Matarese Countdown',
#  'The Cat Who Talked to Ghosts',
#  "Everything's Eventual : 14 Dark Tales",
#  'Girl With a Pearl Earring',
#  'Duplicate Keys',
#  'The Sparrow',
#  'The Magic of You (Malory Novels (Paperback))',
#  'The Ladies of Missalonghi',
#  'Night Sins',
#  "Hornet's Nest",
#  'The Devil Wears Prada : A Novel',
#  'Cold Blooded',
#  'A Theory of Relativity',
#  'Chicken Soup for the Christian Soul (Chicken Soup for the Soul Series (Paper))',
#  'Stalker: A Novel (Peter Decker & Rina Lazarus Novels (Hardcover))',
#  'The Sabbathday River',
#  "Black and Blue (Oprah's Book Club)",
#  'M Is for Malice (Kinsey Millhone Mysteries (Hardcover))',
#  'Silent Witness',
#  'Misty (Wildflowers)',
#  'Tending Roses',
#  'Welcome to My Planet: Where English Is Sometimes Spoken',
#  'Blackbird: A Childhood Lost and Found',
#  'Illusions: The Adventures of a Reluctant Messiah',
#  'The Eye of the World (The Wheel of Time, Book 1)',
#  'The Book Borrower: A Novel',
#  'Billy Bathgate: A Novel',
#  'The Honk and Holler Opening Soon',
#  'Dead Even',
#  'Sleepwalk',
#  'Anne of the Island',
#  'The Guardian',
#  "One Flew Over the Cuckoo's Nest",
#  'It Came From The Far Side',
#  'Cathedral',
#  'Der Vorleser',
#  'Ginger Tree',
#  'Before and After',
#  'Breathing Lessons',
#  'So You Want to Be a Wizard: The First Book in the Young Wizards Series',
#  'Prozac Nation: Young and Depressed in America',
#  'Girl, Interrupted',
#  'The Summerhouse',
#  'A Breach of Promise (William Monk Novels (Paperback))',
#  'Death in Holy Orders (Adam Dalgliesh Mysteries (Hardcover))',
#  'The Cat Who Smelled a Rat (Cat Who... (Paperback))',
#  "Big Cherry Holler: A Big Stone Gap Novel (Ballantine Reader's Circle)",
#  'Summon the Keeper',
#  'Gossip Hound',
#  'A Year by the Sea: Thoughts of an Unfinished Woman',
#  'Magic Hour',
#  'The Red Room',
#  'Lady of Avalon',
#  'Saving Faith',
#  'High Tide in Tucson: Essays from Now or Never',
#  'Hugger Mugger',
#  'Murder Makes Waves (Southern Sisters Mysteries (Paperback))',
#  'The Penwyth Curse',
#  'Night Embrace (Dark-Hunter)',
#  'Burnt Offerings (Anita Blake, Vampire Hunter)',
#  'The Laughing Corpse (Anita Blake Vampire Hunter (Paperback))',
#  'Hearts in Atlantis',
#  'Certain Prey',
#  'Suddenly',
#  'Almost Paradise',
#  'The Haj',
#  'Up Island: A Novel',
#  'Hush Money (Spenser Mysteries)',
#  'Lost Boys',
#  "It's My F---ing Birthday : A Novel",
#  'The Two Dead Girls (Green Mile Series)',
#  'Uh-Oh: Some Observations from Both Sides of the Refrigerator Door',
#  'Dolores Claiborne',
#  "Childhood's End",
#  'The Green Mile: Coffey on the Mile (Green Mile Series)',
#  'Prodigal Summer',
#  "Ahab's Wife: Or, The Star-Gazer: A Novel",
#  'Old Songs in a New Cafe : Selected Essays',
#  "Magic's Price (The Last Herald-Mage Series, Book 3)",
#  'The Morning After',
#  'Transfer of Power',
#  'Send No Flowers',
#  'The Cat Who Tailed a Thief',
#  'Winter Solstice',
#  'The Eyes of the Dragon',
#  "McNally's Gamble (Archy McNally Novels (Paperback))",
#  "McNally's Luck (Archy McNally Novels (Paperback))",
#  'Dealing With Dragons (Enchanted Forest Chronicles (Paperback))',
#  'The Tenth Insight : Holding the Vision',
#  'The Donovan Legacy',
#  'The Last Precinct',
#  'Accordion Crimes',
#  'The Cat Who Brought Down the House',
#  'The Christmas Box Collection : The Christmas Box Timepiece The Letter',
#  'Daughter of Fortune',
#  'The Illuminatus Trilogy: The Eye in the Pyramid, the Golden Apple & Leviathan',
#  'EVEN COWGIRLS GET THE BLUES',
#  'Dr. Death (Alex Delaware Novels (Paperback))',
#  'The Boxcar Children (Boxcar Children, No 1)',
#  'Thurston House',
#  'J Is for Judgment',
#  'Lost Light',
#  "Hitchhikers's Guide to the Galaxy",
#  'Eye Of The Storm (Hudson, Book 3)',
#  'Bel Canto: A Novel',
#  "The Handmaid's Tale : A Novel",
#  'Amber Beach (Donovan)',
#  'The Footprints of God : A Novel',
#  'Across the Nightingale Floor (Tales of the Otori, Book One)',
#  'Prozac Nation: Young and Depressed in America : A Memoir',
#  'Fall on Your Knees',
#  'The Hand That Rocks the Ladle: A Pennsylvania Dutch Mystery With Recipes (Pennsylvania Dutch Mysteries with Recipes (Paperback))',
#  "By the Sword (Kerowyn's Tale)",
#  'If Ever I Return, Pretty Peggy-O',
#  'Seven Years in Tibet',
#  'Dirt',
#  'The Drawing of the Three (The Dark Tower, Book 2)',
#  'The Postman (Bantam Classics)',
#  'Kentucky Sunrise',
#  'The Black Echo (Detective Harry Bosch Mysteries)',
#  'The Encounter (Animorphs , No 3)',
#  'Babyhood',
#  'Jane Eyre (Wordsworth Classics)',
#  'The Attorney',
#  'No Way Out',
#  'Wolves of the Calla (The Dark Tower, Book 5)',
#  'Where the Heart Is: A Novel',
#  'The Calvin and Hobbes Tenth Anniversary Book',
#  'Tuck Everlasting',
#  'Watchers',
#  'Body of Evidence (Kay Scarpetta Mysteries (Paperback))',
#  'The Light Fantastic (Discworld Novels (Paperback))',
#  'Cause Celeb',
#  'Plain and Simple : A Journey to the Amish (Ohio)',
#  'Falling Leaves Brit Edition',
#  'Coast Road: A Novel',
#  'The Angel of Darkness',
#  'Lucky Man: A Memoir',
#  'The Locket : A Novel (Christmas Box Trilogy)',
#  'The Macgregors: Alan - Grant (The Macgregors)',
#  'Long After Midnight',
#  'Being Dead : A Novel',
#  'See Jane Date (Red Dress Ink (Paperback))',
#  'An Ocean Apart',
#  'The Man Who Mistook His Wife for a Hat: And Other Clinical Tales',
#  'The Clinic (Alex Delaware Novels (Paperback))',
#  'Vows',
#  'Dragonsong (Harper Hall Trilogy)',
#  'Deerskin',
#  'Blue Diary',
#  'The Dolphins of Pern (Dragonriders of Pern (Paperback))',
#  'Dead Ringer (Scottoline, Lisa)',
#  'A Natural History of the Senses',
#  'Still Life with Woodpecker',
#  'Guards! Guards! (Discworld Novels (Paperback))',
#  'Family: The Ties That Bind and Gag!',
#  'Only by Your Touch (Signet Books)',
#  'Capital Crimes',
#  'The Ranch',
#  'Fahrenheit 451',
#  'Writing Down the Bones',
#  'Grendel',
#  'SURRENDER THE PINK : SURRENDER THE PINK',
#  'Gorky Park',
#  'Framed in Lace (Needlecraft Mysteries)',
#  'Reunion in Death',
#  'Reliquary',
#  'Stanislaski Sisters',
#  'Murder on a Bad Hair Day: A Southern Sisters Mystery',
#  'The Authoritative Calvin and Hobbes (Calvin and Hobbes)',
#  'Orlando: A Biography',
#  'With This Ring',
#  'Smoke in Mirrors',
#  'The Associate',
#  'Survivor : A Novel',
#  'Acorna: The Unicorn Girl (Acorna (Paperback))',
#  'Strip Tease',
#  'Confessions of a Failed Southern Lady',
#  'Tishomingo Blues',
#  "Kushiel's Dart",
#  'Sacred and Profane (Peter Decker & Rina Lazarus Novels (Paperback))',
#  'Straight Man : A Novel (Vintage Contemporaries)',
#  'The Bride',
#  'Dilbert Fugitive From The Cubicle Police',
#  'Seabiscuit',
#  'Fight Club',
#  'Prelude to Foundation (Foundation Novels (Paperback))',
#  'Amsterdam : A Novel',
#  'On Mystic Lake',
#  'A History of the World in 10 1/2 Chapters (Vintage International)',
#  'Partner in Crime',
#  'Wedding Party',
#  'N Is for Noose',
#  'When I Am an Old Woman I Shall Wear Purple',
#  'The Birth of Venus',
#  'The Charm School',
#  'Scandalous (Banning Sisters Trilogy)',
#  'Cuba Libre',
#  'Santa Fe Rules',
#  'The Claiming of Sleeping Beauty (Sleeping Beauty)',
#  'Dead Run',
#  'After All These Years',
#  'The Color of Magic',
#  'Jackdaws',
#  'A Long Fatal Love Chase',
#  'Silent Partner (Alex Delaware Novels (Paperback))',
#  'The Darwin Awards: Evolution in Action',
#  'Delta Of Venus',
#  'Cows Of Our Planet (Far Side Series)',
#  'Blood Work',
#  'Unspeakable',
#  'The Lords of Discipline',
#  'In a Sunburned Country',
#  'How to Murder a Millionaire',
#  "Having Our Say : The Delany Sisters' First 100 Years",
#  'Apollyon: The Destroyer Is Unleashed (Left Behind #5)',
#  'Ella Minnow Pea: A Novel in Letters',
#  'The Cat Who Moved a Mountain',
#  'To Say Nothing of the Dog',
#  'The Great Train Robbery',
#  'The Reef',
#  'A Girl Named Zippy: Growing Up Small in Mooreland Indiana (Today Show Book Club #3)',
#  'Family: The Ties That Bind and Gag',
#  "The Man from St. Petersburg (#1 Author's Classic Spy Thriller)",
#  'High Tide',
#  'Thunderhead',
#  'Startide Rising (The Uplift Saga, Book 2)',
#  'Dance Hall of the Dead (Joe Leaphorn Novels)',
#  'The Lasko Tangent',
#  'The Fountainhead',
#  'The Ghost Next Door (Goosebumps, No 10)',
#  'The Eleventh Commandment',
#  'The First Horseman',
#  'Prince Charming',
#  'The Thief of Always',
#  'Personal Injuries',
#  'Unbearable Lightness of Being',
#  'The God of Small Things',
#  'Dragons of Winter Night',
#  'I Never Promised You a Rose Garden',
#  'Vittorio the Vampire: New Tales of the Vampires',
#  'Loves Music, Loves to Dance',
#  'On the Banks of Plum Creek',
#  'Final Appeal',
#  'Into the Wild',
#  'Aquitaine Progression',
#  'Back Roads',
#  'Just the Way You Are',
#  'Something Wonderful',
#  'Vanished',
#  'The BFG',
#  'Seabiscuit: An American Legend',
#  'A Cold Heart (Alex Delaware Novels (Paperback))',
#  'Suicide Blonde',
#  'The Path of Daggers (The Wheel of Time, Book 8)',
#  'Beloved (Plume Contemporary Fiction)',
#  'The Music of the Spheres',
#  'Toxin',
#  'Flesh and Blood',
#  'Colony',
#  'Day of Confession',
#  'Texas',
#  'Blackwood Farm (Rice, Anne, Vampire Chronicles.)',
#  'Red Phoenix',
#  'The Diamond Age',
#  'Strangers in the Night',
#  'Welcome to the Monkey House',
#  "A Fever in the Heart : Ann Rule's Crime Files, Volume III",
#  'Good in Bed',
#  'Slammerkin',
#  'Sacred Sins',
#  'Women in His Life',
#  'The Girl Who Loved Tom Gordon : A Novel',
#  'Stiff: The Curious Lives of Human Cadavers',
#  'The Mermaids Singing',
#  'One Night of Scandal',
#  'Meditations for Women Who Do Too Much - 10th Anniversary',
#  'Flesh Tones: A Novel',
#  'Floaters',
#  'Drop Shot (Myron Bolitar Mysteries (Paperback))',
#  'A Holiday Of Love',
#  'Catering to Nobody',
#  'The Vile Village (A Series of Unfortunate Events, Book 7)',
#  'The Ape Who Guards the Balance : An Amelia Peabody Mystery',
#  'Soul Stories',
#  'Lake Wobegon days',
#  'Point of Origin',
#  'A Woman of Substance',
#  'The Bluest Eye',
#  'The Cat Who Went Up the Creek',
#  'Writ of Execution',
#  'Der Campus.',
#  'The GREAT GATSBY (Scribner Classic)',
#  'Bookends : A Novel',
#  'Serpent : A Novel from the NUMA Files (Numa Files Series)',
#  'Soul Mountain',
#  'Secrets',
#  'Praying for Sleep',
#  'Guardian',
#  'Basket Case',
#  'What to Expect the First Year',
#  'The Ice Limit',
#  'The Carousel',
#  'The Egypt Game (Yearling Newbery)',
#  'To Ride a Silver Broomstick: New Generation Witchcraft',
#  'Killing Time: A Novel of the Future',
#  "The Venetian's Wife: A Strangely Sensual Tale of a Renaissance Explorer, a Computer, and a Metamorphosis",
#  'The Jester',
#  'And Then There Were None : A Novel',
#  'Koko',
#  'Hidden Jewel (Landry)',
#  'Running with Scissors: A Memoir',
#  'The Face',
#  'Weirdos From Another Planet!',
#  'Private Eyes (Alex Delaware Novels (Paperback))',
#  "It's Not About the Bike: My Journey Back to Life",
#  'Manner of Death',
#  'Chicken Soup for the Teenage Soul II (Chicken Soup for the Soul Series)',
#  'The Gift',
#  'Night Prey',
#  'Confessions of a Shopaholic (Summer Display Opportunity)',
#  'Love in Another Town',
#  'The Alibi',
#  'Life of Pi',
#  'Demolition Angel',
#  'Hornet Flight',
#  "Harry Potter and the Sorcerer's Stone (Book 1)",
#  'The Horse Whisperer',
#  'Blood and Gold (Vampire Chronicles)',
#  'Needful Things: The Last Castle Rock Story',
#  'Armadillo',
#  'Getting Over It',
#  'Dark Force Rising (Star Wars: The Thrawn Trilogy, Vol. 2)',
#  'A Certain Justice (Adam Dalgliesh Mysteries (Paperback))',
#  'Well-Schooled in Murder',
#  'The Elegant Universe: Superstrings, Hidden Dimensions, and the Quest for the Ultimate Theory',
#  'The Bird Artist',
#  'Women Who Run with the Wolves',
#  'Roadwork',
#  'The Summons',
#  'Trial by Fire',
#  "Tom Clancy's Op-Center: Games of State (Tom Clancy's Op Center (Paperback))",
#  "Tom Clancy's Op-Center: Line of Control (Tom Clancy's Op Center (Paperback))",
#  'Dress Your Family in Corduroy and Denim',
#  'The Weight of Water : A Novel Tag: Author of Resistance and Strange Fits of Passion',
#  'The Tenth Justice',
#  'Loyalty in Death',
#  "A Rage To Kill and Other True Cases : Anne Rule's Crime Files, Vol. 6 (Ann Rule's Crime Files)",
#  'Persepolis : The Story of a Childhood (Alex Awards (Awards))',
#  'The Giver (Readers Circle)',
#  'Mercy',
#  'You Belong To Me',
#  'A Wind in the Door (Laurel Leaf Books)',
#  'The Family Tree',
#  'The Descent',
#  'Midnight Runner',
#  'Girls Night',
#  'Charlie and the Chocolate Factory (Puffin Novels)',
#  'Secret History',
#  'Haunted',
#  'Cane River',
#  'Armageddon: The Cosmic Battle of the Ages (Left Behind #11)',
#  'Legal Tender',
#  'Ringworld',
#  'Terminal',
#  'Brain Droppings',
#  'Mutation',
#  'Horse and His Boy',
#  'The Cat Who Lived High',
#  'Living Dead in Dallas (Southern Vampire Mysteries)',
#  'Dragon Tears',
#  'Among the Hidden',
#  'New Vegetarian: Bold and Beautiful Recipes for Every Occasion',
#  'Tyler #3 Wisconsin Wedding (Tyler, No 3)',
#  'Palomino',
#  'Excavation',
#  'An Angel for Emily',
#  'The Midnight Club',
#  'The Talbot Odyssey',
#  'Second Wind',
#  'Simple Abundance:  A Daybook of Comfort and Joy',
#  'The Bookshop : A Novel',
#  'The Hellion',
#  'The Sixteen Pleasures: A Novel',
#  'The Echo',
#  'Birdsong: A Novel of Love and War',
#  'And Never Let Her Go : Thomas Capano: The Deadly Seducer',
#  "Please Stop Laughing at Me: One Woman's Inspirational Story",
#  'Postmortem (Kay Scarpetta Mysteries (Paperback))',
#  'Three Weeks in Paris',
#  'The Lovely Bones',
#  'Irish Girls About Town: An Anthology of Short Stories',
#  'Bloodsucking Fiends: A Love Story',
#  'Dragonsdawn',
#  'The Dark Room',
#  'A Light in the Window (The Mitford Years)',
#  'The Cat Who Turned on and Off (Cat Who... (Paperback))',
#  'Saving Grace',
#  'Flowers In The Attic (Dollanganger)',
#  'Odd Thomas',
#  'El Codigo Da Vinci / The Da Vinci Code',
#  'Faking It',
#  'Sundiver (The Uplift Saga, Book 1)',
#  'The Fall of Hyperion',
#  'Hot Ice',
#  'The Rainmaker',
#  'Domes of Fire: Book One of the Tamuli (Tamuli)',
#  'The Indwelling: The Beast Takes Possession (Left Behind #7)',
#  'Something Under the Bed Is Drooling',
#  'The Girl Who Heard Dragons',
#  'Tribulation Force: The Continuing Drama of Those Left Behind (Left Behind No. 2)',
#  'The Final Judgment',
#  'Hangman',
#  'Dragonwings : Golden Mountain Chronicles: 1903 (Golden Mountain Chronicles)',
#  'Warning Signs',
#  'Briar Rose',
#  '9-11',
#  "Fried Green Tomatoes at the Whistle Stop Cafe (Ballantine Reader's Circle)",
#  'Defend and Betray (William Monk Novels (Paperback))',
#  'LUCKY',
#  'All Quiet on the Western Front',
#  'Lakota Woman',
#  'Like Water for Chocolate : A Novel in Monthly Installments with Recipes, Romances, and Home Remedies',
#  'Dragons of Autumn Twilight (Dragonlance: Dragonlance Chronicles)',
#  'Eaters of the Dead',
#  'Body for Life: 12 Weeks to Mental and Physical Strength',
#  'The Witches of Eastwick',
#  'The Cat Who Blew the Whistle',
#  'High Maintenance',
#  'Chicken Soup for the Soul (Chicken Soup for the Soul)',
#  'Crime and Punishment (Crime & Punishment)',
#  'Time Flies',
#  'The Poet',
#  'Archangel',
#  'My Year of Meats',
#  'Savage Thunder',
#  'A Son of the Circus',
#  'The Phantom of the Opera: The Original Novel',
#  'The Last Don',
#  'Secret Fire',
#  'From the Corner of His Eye',
#  'The Visitor (Animorphs, No 2)',
#  'A Cry In The Night',
#  'Breach of Promise',
#  "The Magician's Assistant",
#  'The Ship Who Searched',
#  'Sunset in St. Tropez',
#  'Sons of Fortune',
#  "She's Come Undone (Oprah's Book Club (Paperback))",
#  'Castles',
#  'The Bear and the Dragon',
#  'Genuine Lies',
#  'Desecration: Antichrist Takes the Throne (Left Behind No. 9)',
#  "Big Stone Gap: A Novel (Ballantine Reader's Circle)",
#  'Pay It Forward',
#  'Crocodile on the Sandbank',
#  'The Night Listener : A Novel',
#  'Angry Housewives Eating Bon Bons',
#  'Blue Skies',
#  'Accident',
#  'Garden of Lies (Signet Shakespeare)',
#  'Cabin',
#  'Holes (Readers Circle)',
#  'Secret History, The',
#  'GARDEN OF SHADOWS (Dollanger Saga (Paperback))',
#  "Acts of War (Tom Clancy's Op Center (Paperback))",
#  "The Idiot Girls' Action Adventure Club",
#  'The Stone Monkey : A Lincoln Rhyme Novel',
#  "I'm Not Really Here",
#  'Rain',
#  'Without Remorse',
#  'Vernon God Little: A 21st Century Comedy in the Presence of Death',
#  'Siddharta Romanzo Versione Di M Mila',
#  'One Last Time: A Psychic Medium Speaks to Those We Have Loved and Lost',
#  'Billy Straight: A Novel',
#  'Murder in the CIA (Capital Crime Mysteries)',
#  'Eyes of Prey',
#  'The Playboy',
#  'Misery',
#  'The Key to Rebecca',
#  'Stones for Ibarra (Penguin Contemporary American Fiction Series)',
#  'One Thousand White Women : The Journals of May Dodd: A Novel',
#  'Coming Home',
#  'Night Pleasures (Dark-Hunters)',
#  'The Outlaws of Sherwood',
#  'Fluke : Or, I Know Why the Winged Whale Sings',
#  'Motherless Brooklyn',
#  'The Secret Life of Bees',
#  'Girl in Hyacinth Blue',
#  'Local Girls',
#  'One Fish Two Fish Red Fish Blue Fish (I Can Read It All by Myself Beginner Books)',
#  'Snowfall',
#  'Man from Mundania (Xanth Trilogy, No 12)',
#  'Extreme Measures',
#  'Remember When',
#  'Plum Island',
#  'Die PÃ?Â¤pstin.',
#  'Ten Big Ones: A Stephanie Plum Novel',
#  'Shell Seekers',
#  'What The Lady Wants',
#  'A Dangerous Fortune',
#  '1984',
#  'Cloud Nine',
#  'A Is for Alibi (Kinsey Millhone Mysteries (Paperback))',
#  'Star',
#  'Firestarter',
#  'Seinlanguage',
#  'The Client',
#  'Nine Parts of Desire: The Hidden World of Islamic Women',
#  'Relic',
#  'M Is for Malice',
#  'The Last Coyote (Last Coyote)',
#  'Parallel Lies',
#  'Heart Song (Logan)',
#  'Remember When (Roberts, Nora)',
#  'Lolita (Vintage International)',
#  'The Empty Chair',
#  'Keepsake Crimes (First Scrapbooking Mystery)',
#  'Seventh Son (Tales of Alvin Maker, Book 1)',
#  'Bleachers',
#  'The Poisonwood Bible',
#  'Doctors',
#  'The Case Has Altered: A Richard Jury Mystery (Richard Jury Mysteries (Paperback))',
#  'The Eyre Affair (Alex Awards (Awards))',
#  'The Diary of Ellen Rimbauer: My Life at Rose Red',
#  'The Murder Book',
#  'The Villa',
#  'If You Really Loved Me',
#  'Bare Bones : A Novel',
#  'The A.B.C. Murders',
#  'Spandau Phoenix',
#  'The Copper Beech',
#  'The Burning Man',
#  'Rough Justice',
#  'The Art of Happiness: A Handbook for Living',
#  'Man of My Dreams (Sherring Cross (Paperback))',
#  'Final Flight',
#  'Garden of Rama',
#  'Into the Night',
#  'Stillwatch',
#  'Autobiography of a Fat Bride : True Tales of a Pretend Adulthood',
#  'Pride and Prejudice (Dover Thrift Editions)',
#  'Tapestry',
#  'Lady Be Good (Avon Romance)',
#  'Lullaby: A Novel',
#  'Crystal (Orphans)',
#  'Golden Orange',
#  'Lily White',
#  'Come the Spring (Clayborne Brothers)',
#  'The Lord of the Rings (Movie Art Cover)',
#  'Cadillac Jukebox (Dave Robicheaux Mysteries (Paperback))',
#  "I Know This Much Is True (Oprah's Book Club)",
#  'Fatherhood',
#  'Bad Heir Day',
#  'A Patchwork Planet',
#  'The Perfect Storm : A True Story of Men Against the Sea',
#  'Coyote Waits (Joe Leaphorn/Jim Chee Novels)',
#  'Reading Lolita in Tehran: A Memoir in Books',
#  'Charming Billy',
#  'Lasher',
#  'Protein Power: The High-Protein/Low Carbohydrate Way to Lose Weight, Feel Fit, and Boost Your Health-in Just Weeks!',
#  'Kiss the Girls',
#  'Dharma Bums',
#  'Stranger in Paradise (A Carson Springs Novel, Book 1)',
#  "The Girls' Guide to Hunting and Fishing",
#  'SEEDS OF YESTERDY (Dollanger Saga (Paperback))',
#  'More Than a Carpenter',
#  'The Probable Future',
#  'Heaven',
#  'Hot Springs (Earl Swagger Novels (Paperback))',
#  'Deadly Decisions',
#  'Speaker for the Dead (Ender Wiggins Saga (Paperback))',
#  'Blessings : A Novel',
#  'ROAD LESS TRAVELED : A New Psychology of Love, Traditional Values, and Spritual Growth (Touchstone Books (Paperback))',
#  'Succulent Wild Woman',
#  'Out Of The Dark',
#  'Dragonquest (Dragonquest)',
#  'An Instance of the Fingerpost',
#  'A Heartbreaking Work of Staggering Genius',
#  'The Cottage',
#  'Word Freak: Heartbreak, Triumph, Genius, and Obsession in the World of Competitive Scrabble Players',
#  'Lies My Teacher Told Me : Everything Your American History Textbook Got Wrong',
#  'The Color Purple',
#  'Tunnel Vision (V.I. Warshawski Novels (Paperback))',
#  'Simplify Your Life : 100 Ways to Slow Down and Enjoy the Things That Really Matter',
#  'Fire Ice: A Novel from the Numa Files (Kurt Austin Adventures (Paperback))',
#  'WATER WITCHES',
#  'George W. Bushisms : The Slate Book of The Accidental Wit and Wisdom of our 43rd President',
#  'He, She and It',
#  "Pope Joan (Ballantine Reader's Circle)",
#  'Catherine, Called Birdy (Trophy Newbery)',
#  'The Four Agreements: A Practical Guide to Personal Freedom',
#  'Castle of Wizardry (The Belgariad, Book 4)',
#  'Ceremony (Contemporary American Fiction Series)',
#  'All That Remains (Kay Scarpetta Mysteries (Paperback))',
#  'What You Wish for',
#  'All That Glitters (Landry)',
#  'Keeper of the Heart',
#  'The Sigma Protocol',
#  'Dinopark/Jurassic Park',
#  'Brick Lane: A Novel',
#  'A Wind in the Door',
#  'Violets Are Blue',
#  "Let's Get Invisible! (Goosebumps, No 6)",
#  'Catch As Cat Can',
#  'Presumed Innocent',
#  'Hidden Fires',
#  'Midnight Whispers (Cutler)',
#  'Island of the Sequined Love Nun',
#  'The Mystery of the Cupboard (Indian in the Cupboard)',
#  'The Cradle Will Fall',
#  'A Heartbreaking Work Of Staggering Genius : A Memoir Based on a True Story',
#  'The Gold Coast',
#  'Mutant Message Down Under',
#  'Mr. Perfect',
#  "Bio-Strike (Tom Clancy's Power Plays (Paperback))",
#  "Then Again, Maybe I Won't",
#  "CAT'S EYE",
#  "Bill Bryson's African Diary",
#  'SAHARA',
#  'Tall, Dark, and Deadly',
#  "Lord Foul's Bane (The Chronicles of Thomas Covenant the Unbeliever, Book 1)",
#  'Nerd in Shining Armor',
#  'The Sculptress (Sculptress)',
#  'The Naked Face',
#  "Stephen King's Danse Macabre",
#  "Thursday'S At Eight",
#  'The Fallen Man (Joe Leaphorn Novels)',
#  '1st to Die: A Novel',
#  'The Life and Loves of a She-Devil',
#  'Walking Across Egypt',
#  'Hellion Bride (Bride Trilogy (Paperback))',
#  'Dark Water (Mira Romantic Suspense)',
#  "Chicken Soup for the Cat and Dog Lover's Soul - Celebrating Pets as Family with Stories About Cats, Dogs and Other Critters",
#  'Snow Crash (Bantam Spectra Book)',
#  'I Is for Innocent',
#  'Summer Pleasures',
#  'The Beach House',
#  'Reap the Wind',
#  ...]

# %% [markdown]
# ### Modelo TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
books = ratings['Book-Title'].unique()
books
# Out:
# array(["The Kitchen God's Wife", 'The Testament',
#        'Beloved (Plume Contemporary Fiction)', ...,
#        'Paddy Clarke Ha Ha Ha', 'A Tangled Web',
#        'The Purpose-Driven Life: What on Earth Am I Here For?'],
#       dtype=object)

# %%
def convert_to_list(sentence):
    # Check characters to see if they are in punctuation
    nopunc = [char for char in sentence if char not in string.punctuation]
    #print(nopunc)
    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    #print(nopunc)
    # Now just remove any stopwords
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
books_word = []
for title in books:
    books_word.append(convert_to_list(title))
books_word
# Out:
# [['Kitchen', 'Gods', 'Wife'],
#  ['Testament'],
#  ['Beloved', 'Plume', 'Contemporary', 'Fiction'],
#  ['New', 'Vegetarian', 'Bold', 'Beautiful', 'Recipes', 'Every', 'Occasion'],
#  ['Wild', 'Animus'],
#  ['Airframe'],
#  ['Timeline'],
#  ['Kill', 'Mockingbird'],
#  ['Seabiscuit', 'American', 'Legend'],
#  ['Pigs', 'Heaven'],
#  ['Downtown'],
#  ['Ill', 'Seeing'],
#  ['Corner', 'Eye'],
#  ['Isle', 'Dogs'],
#  ['Purity', 'Death'],
#  ['Year', 'Different', 'Stories'],
#  ['Left', 'Behind', 'Novel', 'Earths', 'Last', 'Days', 'Left', 'Behind', '1'],
#  ['Street', 'Lawyer'],
#  ['LONESOME', 'DOVE'],
#  ['Breathing', 'Lessons'],
#  ['Joy', 'Luck', 'Club'],
#  ['Tao', 'Pooh'],
#  ['Seabiscuit'],
#  ['Lifes',
#   'Little',
#   'Instruction',
#   'Book',
#   'Lifes',
#   'Little',
#   'Instruction',
#   'Books',
#   'Paperback'],
#  ['Starship', 'Troopers'],
#  ['Ruby', 'Smoke', 'Sally', 'Lockhart', 'Trilogy', 'Book', '1'],
#  ['Catcher', 'Rye'],
#  ['Midnight', 'Garden', 'Good', 'Evil', 'Savannah', 'Story'],
#  ['Pretend', 'Dont', 'See'],
#  ['Rich',
#   'Dad',
#   'Poor',
#   'Dad',
#   'Rich',
#   'Teach',
#   'Kids',
#   'MoneyThat',
#   'Poor',
#   'Middle',
#   'Class'],
#  ['Pillars', 'Earth'],
#  ['Corellis', 'Mandolin', 'Novel'],
#  ['Five', 'People', 'Meet', 'Heaven'],
#  ['Alibi'],
#  ['Beach', 'House'],
#  ['Short', 'Forever'],
#  ['Dead', 'Aim'],
#  ['Angels', 'Demons'],
#  ['Ever', 'Wanted', 'Novel'],
#  ['Every',
#   'Breath',
#   'Take',
#   'True',
#   'Story',
#   'Obsession',
#   'Revenge',
#   'Murder'],
#  ['Mosquito', 'Coast'],
#  ['Girl', 'Loved', 'Tom', 'Gordon'],
#  ['Sum', 'Fears'],
#  ['One', 'Hundred', 'Years', 'Solitude'],
#  ['Little', 'Altars', 'Everywhere', 'Novel'],
#  ['Coyote', 'Waits', 'Joe', 'LeaphornJim', 'Chee', 'Novels'],
#  ['Say', 'GoodBye'],
#  ['Slow', 'Waltz', 'Cedar', 'Bend'],
#  ['Atonement', 'Novel'],
#  ['Hush'],
#  ['Whisper', 'Evil', 'Hooper', 'Kay', 'Evil', 'Trilogy'],
#  ['Rebecca'],
#  ['Diary', 'Mad', 'MomToBe'],
#  ['Puerto', 'Vallarta', 'Squeeze'],
#  ['Wish', 'Well'],
#  ['Hitchhikers', 'Guide', 'Galaxy'],
#  ['Crow', 'Lake', 'Today', 'Show', 'Book', 'Club', '7'],
#  ['Pen', 'Pals'],
#  ['Bridget', 'Joness', 'Diary'],
#  ['Pride', 'Prejudice', 'Dover', 'Thrift', 'Editions'],
#  ['Martian', 'Chronicles'],
#  ['God', 'Small', 'Things'],
#  ['Big', 'Bad', 'Wolf', 'Novel'],
#  ['Four', 'Blind', 'Mice'],
#  ['Private', 'Screening'],
#  ['Congo'],
#  ['Protect', 'Defend'],
#  ['Memoirs', 'Geisha'],
#  ['Plainsong', 'Vintage', 'Contemporaries'],
#  ['Body', 'Evidence', 'Kay', 'Scarpetta', 'Mysteries', 'Paperback'],
#  ['Remains', 'Kay', 'Scarpetta', 'Mysteries', 'Paperback'],
#  ['Brethren'],
#  ['King', 'Torts'],
#  ['Curious', 'Incident', 'Dog', 'NightTime', 'Novel'],
#  ['Bleachers'],
#  ['Sisterhood', 'Traveling', 'Pants'],
#  ['Roses', 'Red', 'Alex', 'Cross', 'Novels'],
#  ['Rescue'],
#  ['Manhattan', 'Hunt', 'Club'],
#  ['Patty', 'Janes', 'House', 'Curl', 'Ballantine', 'Readers', 'Circle'],
#  ['Pet', 'Sematary'],
#  ['Silent', 'Snow'],
#  ['Girl', 'Pearl', 'Earring'],
#  ['Summer', 'Storms'],
#  ['Patient'],
#  ['Postmortem', 'Kay', 'Scarpetta', 'Mysteries', 'Paperback'],
#  ['Deception', 'Point'],
#  ['Tis', 'Memoir'],
#  ['Monk', 'Swimming'],
#  ['Kalahari', 'Typing', 'School', 'Men', '1', 'Ladies', 'Detective', 'Agency'],
#  ['Chicken', 'Soup', 'Soul', 'Chicken', 'Soup', 'Soul'],
#  ['Wicked', 'Life', 'Times', 'Wicked', 'Witch', 'West'],
#  ['Life', 'Pi'],
#  ['Lies', 'Lying', 'Liars', 'Tell', 'Fair', 'Balanced', 'Look', 'Right'],
#  ['Secret', 'History'],
#  ['Chicken',
#   'Soup',
#   'Womans',
#   'Soul',
#   'Chicken',
#   'Soup',
#   'Soul',
#   'Series',
#   'Paper'],
#  ['Weight', 'Water'],
#  ['Bright',
#   'Side',
#   'Im',
#   'Girlfriend',
#   'Sex',
#   'God',
#   'Confessions',
#   'Georgia',
#   'Nicolson'],
#  ['Confessions', 'Shopaholic'],
#  ['Making', 'Minty', 'Malone'],
#  ['Emma', 'Signet', 'Classics', 'Paperback'],
#  ['Animal', 'Farm'],
#  ['Eva', 'Luna'],
#  ['Catch', '22'],
#  ['League', 'Extraordinary', 'Gentlemen', 'Vol', '1'],
#  ['Man', 'Full'],
#  ['Miracle', 'Life', 'Edgar', 'Mint', 'Novel'],
#  ['October', 'Sky', 'Memoir'],
#  ['Painted', 'House'],
#  ['Perfect', 'Storm', 'True', 'Story', 'Men', 'Sea'],
#  ['Postman', 'Bantam', 'Classics'],
#  ['Neanderthal', 'Novel'],
#  ['Frankenstein', 'Dover', 'Thrift', 'Editions'],
#  ['Vinegar', 'Hill', 'Oprahs', 'Book', 'Club', 'Paperback'],
#  ['Affinity'],
#  ['Best',
#   'Democracy',
#   'Money',
#   'Buy',
#   'Truth',
#   'Corporate',
#   'Cons',
#   'Globalization',
#   'HighFinance',
#   'Fraudsters'],
#  ['Hunt', 'Red', 'October'],
#  ['Liberty', 'Falling', 'Anna', 'Pigeon', 'Mysteries', 'Paperback'],
#  ['Bel', 'Canto'],
#  ['James', 'Giant', 'Peach'],
#  ['Secret', 'Life', 'Bees'],
#  ['Digital', 'Fortress', 'Thriller'],
#  ['Ladies', 'Missalonghi'],
#  ['Blackberry', 'Wine', 'Novel'],
#  ['Irish',
#   'Saved',
#   'Civilization',
#   'Untold',
#   'Story',
#   'Irelands',
#   'Heroic',
#   'Role',
#   'Fall',
#   'Rome',
#   'Rise',
#   'Medieval',
#   'Europe',
#   'Hinges',
#   'History'],
#  ['Client'],
#  ['Heart', 'Sea', 'Irish', 'Trilogy'],
#  ['Lake', 'News'],
#  ['Accidental', 'Woman'],
#  ['Year', 'Sea', 'Thoughts', 'Unfinished', 'Woman'],
#  ['Little', 'Prince'],
#  ['Jonathan', 'Livingston', 'Seagull'],
#  ['Alices', 'Adventures', 'Wonderland', 'Looking', 'Glass'],
#  ['Moonlight', 'Becomes'],
#  ['Divine', 'Secrets', 'YaYa', 'Sisterhood', 'Novel'],
#  ['Lakota', 'Woman'],
#  ['Lovely', 'Bones', 'Novel'],
#  ['Hannibal'],
#  ['London', 'Novel'],
#  ['Robber', 'Bride'],
#  ['Prozac', 'Nation', 'Young', 'Depressed', 'America', 'Memoir'],
#  ['Four', 'Agreements', 'Practical', 'Guide', 'Personal', 'Freedom'],
#  ['War', 'Peace', 'Wordsworth', 'Classics'],
#  ['Dragonflight', 'Dragonriders', 'Pern', 'Trilogy', 'Paperback'],
#  ['Firm'],
#  ['Murder', 'Kennedy', 'Center', 'Capital', 'Crime', 'Mysteries'],
#  ['Scarlet', 'Letter'],
#  ['Dragonsong', 'Harper', 'Hall', 'Trilogy'],
#  ['Cloud', 'Nine'],
#  ['Lovely', 'Bones'],
#  ['Tortilla', 'Curtain'],
#  ['Widow', 'One', 'Year'],
#  ['Empire', 'Falls'],
#  ['Oryx', 'Crake'],
#  ['Black', 'Blue'],
#  ['Le', 'Divorce', 'William', 'Abrahams', 'Book'],
#  ['Face'],
#  ['Shes', 'Come', 'Undone', 'Oprahs', 'Book', 'Club'],
#  ['Falling', 'Leaves', 'True', 'Story', 'Unwanted', 'Chinese', 'Daughter'],
#  ['Nickel', 'Dimed', 'Getting', 'America'],
#  ['RUSSIA', 'HOUSE'],
#  ['First', 'Wives', 'Club', 'Movie', 'Tie'],
#  ['Left', 'Behind', 'Novel', 'Earths', 'Last', 'Days', 'Left', 'Behind', '1'],
#  ['Letters', 'Nut'],
#  ['Shining'],
#  ['Diary', 'Ellen', 'Rimbauer', 'Life', 'Rose', 'Red'],
#  ['Sky', 'Falling'],
#  ['Cool'],
#  ['Bean', 'Trees'],
#  ['Homeland', 'Stories'],
#  ['Daughter', 'Fortune'],
#  ['Fly', 'Wall'],
#  ['Red', 'Tent', 'Bestselling', 'Backlist'],
#  ['Blue',
#   'Last',
#   'Richard',
#   'Jury',
#   'Mystery',
#   'Richard',
#   'Jury',
#   'Mysteries',
#   'Paperback'],
#  ['Nanny', 'Diaries', 'Novel'],
#  ['Confessions',
#   'Sociopathic',
#   'Social',
#   'Climber',
#   'Katya',
#   'Livingston',
#   'Chronicles',
#   'Katya',
#   'Livingston',
#   'Chronicles',
#   'Hardcover'],
#  ['Postmortem'],
#  ['Cove'],
#  ['Inconvenient', 'Woman'],
#  ['Shock', 'Wave', 'Dirk', 'Pitt', 'Adventures', 'Paperback'],
#  ['Pretty', 'One', 'Sleeps'],
#  ['Everything', 'Illuminated', 'Novel'],
#  ['Three', 'Junes'],
#  ['Back', 'Roads'],
#  ['Shoes', 'Novel'],
#  ['Kiss'],
#  ['Sweet', 'Hereafter', 'Movie', 'TieIn', 'Novel'],
#  ['Country', 'RI'],
#  ['Brazen', 'Virtue'],
#  ['Ghost', 'Moon'],
#  ['Strangers'],
#  ['Milk', 'Honey', 'Peter', 'DeckerRina', 'Lazarus', 'Novels'],
#  ['Deep', 'End', 'Ocean', 'Oprahs', 'Book', 'Club'],
#  ['Night', 'Tales'],
#  ['Thousand', 'Acres', 'Ballantine', 'Readers', 'Circle'],
#  ['Chopping', 'Spree'],
#  ['Four', 'Blondes'],
#  ['Rivers', 'End'],
#  ['Summer', 'Island'],
#  ['Straw', 'Men'],
#  ['Chamber'],
#  ['Warlock', 'Novel', 'Ancient', 'Egypt'],
#  ['Partner'],
#  ['Chosen', 'Prey'],
#  ['Guilty', 'Sin'],
#  ['Night', 'Sins'],
#  ['Second', 'Time', 'Around', 'Novel'],
#  ['Prince', 'Caspian'],
#  ['Abduction'],
#  ['Never', 'Let', 'Go', 'Thomas', 'Capano', 'Deadly', 'Seducer'],
#  ['Vampire', 'Lestat', 'Vampire', 'Chronicles', 'Book', 'II'],
#  ['Mummy', 'Ramses', 'Damned'],
#  ['Mothers', 'Daughter'],
#  ['Organizing', 'Inside'],
#  ['Vanished'],
#  ['Morning'],
#  ['Hiding', 'Shadows', 'Shadows', 'Trilogy', 'Paperback'],
#  ['Kitchen', 'Privileges', 'Memoir'],
#  ['Cold', 'Mountain', 'MTI', 'Vintage', 'Contemporaries'],
#  ['Daisy', 'Fay', 'Miracle', 'Man'],
#  ['Angelas', 'Ashes', 'Memoir'],
#  ['Next', 'Accident'],
#  ['Amber', 'Spyglass', 'Dark', 'Materials', 'Book', '3'],
#  ['Subtle', 'Knife', 'Dark', 'Materials', 'Book', '2'],
#  ['Golden', 'Compass', 'Dark', 'Materials', 'Book', '1'],
#  ['Ever', 'Return', 'Pretty', 'PeggyO'],
#  ['Rosewood', 'Casket'],
#  ['Fast', 'Food', 'Nation', 'Dark', 'Side', 'AllAmerican', 'Meal'],
#  ['Kissing', 'Manhattan'],
#  ['Echoes'],
#  ['Someone', 'Watch', 'Novel'],
#  ['One', 'Money', 'Stephanie', 'Plum', 'Novels', 'Paperback'],
#  ['Bell', 'Jar', 'Novel', 'Perennial', 'Classics'],
#  ['Dark', 'Lady'],
#  ['Future', 'Scrolls'],
#  ['Face'],
#  ['Along', 'Came', 'Spider', 'Alex', 'Cross', 'Novels'],
#  ['Simple', 'Abundance', 'Daybook', 'Comfort', 'Joy'],
#  ['River', 'King'],
#  ['Final', 'Appeal'],
#  ['Moved', 'Cheese', 'Amazing', 'Way', 'Deal', 'Change', 'Work', 'Life'],
#  ['Road', 'Penguin', '20th', 'Century', 'Classics'],
#  ['OLD', 'MAN', 'SEA'],
#  ['Heart', 'Oprahs', 'Book', 'Club', 'Paperback'],
#  ['Girls', 'Guide', 'Hunting', 'Fishing'],
#  ['Icy', 'Sparks'],
#  ['True', 'Outstanding', 'Adventures', 'Hunt', 'Sisters', 'Novel'],
#  ['Time', 'Travelers', 'Wife'],
#  ['Strange', 'Fits', 'Passion', 'Novel'],
#  ['Sense', 'Sensibility', 'Penguin', 'Popular', 'Classics'],
#  ['Da', 'Vinci', 'Code'],
#  ['Bridget', 'Jones', 'Edge', 'Reason'],
#  ['Pilots',
#   'Wife',
#   'Novel',
#   'Tag',
#   'Author',
#   'Weight',
#   'Water',
#   'Oprahs',
#   'Book',
#   'Club',
#   'Hardcover'],
#  ['Big', 'Trouble'],
#  ['Snow', 'Falling', 'Cedars'],
#  ['Skipping', 'Christmas'],
#  ['Reader'],
#  ['Daddys', 'Little', 'Girl'],
#  ['Vineyard', 'Novel'],
#  ['True'],
#  ['Message', 'Bottle'],
#  ['Blackbird', 'Childhood', 'Lost', 'Found'],
#  ['Guardian'],
#  ['Nights', 'Rodanthe'],
#  ['Like',
#   'Water',
#   'Chocolate',
#   'Novel',
#   'Monthly',
#   'Installments',
#   'Recipes',
#   'Romances',
#   'Home',
#   'Remedies'],
#  ['Two', 'Towers', 'Lord', 'Rings', 'Part', '2'],
#  ['Perfect', 'Storm', 'True', 'Story', 'Men', 'Sea'],
#  ['Villa'],
#  ['Mountain'],
#  ['Pretty', 'Horses', 'Border', 'Trilogy', 'Vol', '1'],
#  ['Suzannes', 'Diary', 'Nicholas'],
#  ['Sees', 'Youre', 'Sleeping', 'Novel'],
#  ['2nd', 'Chance'],
#  ['Voice', 'Eagle'],
#  ['Bad', 'Beginning', 'Series', 'Unfortunate', 'Events', 'Book', '1'],
#  ['Wasp', 'Factory'],
#  ['George',
#   'W',
#   'Bushisms',
#   'Slate',
#   'Book',
#   'Accidental',
#   'Wit',
#   'Wisdom',
#   '43rd',
#   'President'],
#  ['Les', 'Fourmis'],
#  ['Amy', 'Isabelle'],
#  ['Talk', 'Pretty', 'One', 'Day'],
#  ['stardust'],
#  ['Door', 'December'],
#  ['Funhouse'],
#  ['Density', 'Souls'],
#  ['Boy', 'Movie', 'TieIn'],
#  ['Dreamcatcher'],
#  ['People', 'Wolf', 'First', 'North', 'Americans', 'series', 'Book', '1'],
#  ['Smillas', 'Sense', 'Snow'],
#  ['Music', 'Dolphins', 'Apple', 'Signature', 'Edition'],
#  ['Want', 'Wizard', 'First', 'Book', 'Young', 'Wizards', 'Series'],
#  ['Giver', '21st', 'Century', 'Reference'],
#  ['Die', 'SÃÂ¤ulen', 'der', 'Erde', 'Roman'],
#  ['Mirror', 'Dreams', 'Mordants', 'Need'],
#  ['Reader'],
#  ['Dead', 'Zone'],
#  ['LONG', 'DARK', 'TEA', 'TIME', 'SOUL'],
#  ['Better', 'Worse', 'Novel'],
#  ['Forest', 'House'],
#  ['Bear', 'Dragon'],
#  ['Net', 'Force'],
#  ['Time', 'Kill'],
#  ['Awakening'],
#  ['Patriot', 'Games'],
#  ['Chasing', 'Dime'],
#  ['Cat', 'Tailed', 'Thief'],
#  ['Guilt'],
#  ['Charming', 'Billy'],
#  ['Golden', 'Cup'],
#  ['Safe', 'Place'],
#  ['Granny', 'Dan'],
#  ['Penwyth', 'Curse'],
#  ['Lord', 'Silent', 'Novel', 'Suspense'],
#  ['Wuthering', 'Heights'],
#  ['Stars', 'Shine'],
#  ['Toxin'],
#  ['Mothman', 'Prophecies'],
#  ['Dark', 'Paradise'],
#  ['Middlesex', 'Novel'],
#  ['Rainmaker'],
#  ['Bad', 'Place'],
#  ['Amazing', 'Adventures', 'Kavalier', 'Clay'],
#  ['Phantom', 'Tollbooth'],
#  ['Dances', 'Wolves'],
#  ['Princess',
#   'Bride',
#   'Morgensterns',
#   'Classic',
#   'Tale',
#   'True',
#   'Love',
#   'High',
#   'Adventure'],
#  ['Natural', 'Causes'],
#  ['Degree', 'Guilt'],
#  ['Wuthering', 'Heights', 'Penguin', 'Popular', 'Classics'],
#  ['Emma', 'Penguin', 'Popular', 'Classics'],
#  ['Fight', 'Club'],
#  ['SHIPPING', 'NEWS'],
#  ['Frog', 'King', 'Love', 'Story'],
#  ['Smoke', 'Jumper'],
#  ['Unbearable', 'Lightness'],
#  ['Spell', 'Chameleon', 'Xanth', 'Novels', 'Paperback'],
#  ['Anne', 'Green', 'Gables', 'Anne', 'Green', 'Gables', 'Novels', 'Paperback'],
#  ['Everything', 'Illuminated', 'Novel'],
#  ['Road', 'Essentialpenguin'],
#  ['Norwegian', 'Wood', 'Vintage', 'International', 'Original'],
#  ['Fall', 'Knees', 'Oprah', '45'],
#  ['Reap', 'Wind'],
#  ['Survivors', 'Club'],
#  ['Carousel'],
#  ['Gone'],
#  ['Grass'],
#  ['One',
#   'Fish',
#   'Two',
#   'Fish',
#   'Red',
#   'Fish',
#   'Blue',
#   'Fish',
#   'Read',
#   'Beginner',
#   'Books'],
#  ['World', 'According', 'Garp', 'Ballantine', 'Readers', 'Circle'],
#  ['Farewell', 'Arms'],
#  ['Possessing', 'Secret', 'Joy'],
#  ['Angle', 'Repose', 'Contemporary', 'American', 'Fiction'],
#  ['White', 'Noise', 'Contemporary', 'American', 'Fiction'],
#  ['Invisible', 'Man'],
#  ['Love', 'Shadows'],
#  ['House', 'Spirits'],
#  ['Sidewalk', 'Ends', 'Poems', 'Drawings'],
#  ['Interpreter', 'Maladies'],
#  ['Divine', 'Secrets', 'YaYa', 'Sisterhood', 'Novel'],
#  ['Shes', 'Come', 'Undone', 'Oprahs', 'Book', 'Club', 'Paperback'],
#  ['JITTERBUG', 'PERFUME'],
#  ['Dragonfly', 'Amber'],
#  ['Naked'],
#  ['Writing', 'Bones'],
#  ['K', 'Killer', 'Grafton', 'Sue', 'Kinsey', 'Millhone', 'Mysteries'],
#  ['Ironweed'],
#  ['Grapes', 'Wrath'],
#  ['CUCKOOS', 'EGG'],
#  ['Kiss', 'Girls'],
#  ['Different', 'Seasons'],
#  ['Witching', 'Hour', 'Lives', 'Mayfair', 'Witches'],
#  ['Jack', 'Jill', 'Alex', 'Cross', 'Novels'],
#  ['Vittorio', 'Vampire', 'New', 'Tales', 'Vampires'],
#  ['House', 'Mango', 'Street', 'Vintage', 'Contemporaries'],
#  ['DemonHaunted', 'World', 'Science', 'Candle', 'Dark'],
#  ['Verge', 'Red', 'Dress', 'Ink', 'Paperback'],
#  ['Welcome', 'Planet', 'English', 'Sometimes', 'Spoken'],
#  ['Love', 'Users', 'Guide'],
#  ['Perks', 'Wallflower'],
#  ['Daughter', 'Fortune', 'Novel', 'Oprahs', 'Book', 'Club', 'Hardcover'],
#  ['Portrait', 'Sepia'],
#  ['Dharma', 'Bums'],
#  ['American', 'Gods'],
#  ['2061', 'Odyssey', 'Three'],
#  ['Tales', 'City', 'Tales', 'City', 'Series', 'V', '1'],
#  ['Red', 'Dragon'],
#  ['Jurassic', 'Park'],
#  ['Trading', 'Places'],
#  ['Stanislaski', 'Brothers', 'Silhouette', 'Promo'],
#  ['Neverwhere'],
#  ['Thorn', 'Birds'],
#  ['Forever', 'Novel', 'Good', 'Evil', 'Love', 'Hope'],
#  ['Beekeepers', 'Apprentice'],
#  ['Mother', 'Pearl'],
#  ['Picture', 'Dorian', 'Gray'],
#  ['Der', 'Alchimist'],
#  ['Breakfast',
#   'Tiffanys',
#   'Three',
#   'Stories',
#   'First',
#   'Vintage',
#   'International'],
#  ['Angelas', 'Ashes'],
#  ['Memoirs', 'Geisha', 'Uk'],
#  ['Last', 'Dance', 'Last', 'Chance', 'Ann', 'Rules', 'Crime', 'Files'],
#  ['Choke'],
#  ['Survivor', 'Novel'],
#  ['Lamb', 'Gospel', 'According', 'Biff', 'Christs', 'Childhood', 'Pal'],
#  ['Lake', 'Wobegon', 'Days'],
#  ['Rush', 'Limbaugh', 'Big', 'Fat', 'Idiot', 'Observations'],
#  ['Dealing', 'Dragons', 'Enchanted', 'Forest', 'Chronicles', 'Paperback'],
#  ['Human', 'Political', 'Education'],
#  ['Thief', 'Lord'],
#  ['Return', 'Jedi', 'Star', 'Wars'],
#  ['Color', 'Water', 'Black', 'Mans', 'Tribute', 'White', 'Mother'],
#  ['Wayside', 'School', 'Falling'],
#  ['Anne', 'Frank', 'Diary', 'Young', 'Girl'],
#  ['Elfstones', 'Shannara'],
#  ['Stand', 'Complete', 'Uncut'],
#  ['Lonesome', 'Dove'],
#  ['Shopaholic', 'Takes', 'Manhattan', 'Summer', 'Display', 'Opportunity'],
#  ['Confessions', 'Shopaholic', 'Summer', 'Display', 'Opportunity'],
#  ['Cider', 'House', 'Rules'],
#  ['Summer', 'Light'],
#  ['Smoke', 'Mirrors'],
#  ['Table', 'Two'],
#  ['Education', 'Little', 'Tree', 'Zia', 'Book'],
#  ['Darwins', 'Radio'],
#  ['Good', 'Omens'],
#  ['Songcatcher', 'Ballad', 'Novel'],
#  ['Fatal', 'Voyage'],
#  ['Praying', 'Sleep'],
#  ['Red', 'Square'],
#  ['Pearl', 'Mist', 'Landry'],
#  ['Shock'],
#  ['Poisonwood', 'Bible', 'Novel'],
#  ['Lesson', 'Dying', 'Vintage', 'Contemporaries', 'Paperback'],
#  ['Operating', 'Instructions', 'Journal', 'Sons', 'First', 'Year'],
#  ['Jewel'],
#  ['Eyes', 'Watching', 'God', 'Novel'],
#  ['Notes', 'Small', 'Planet'],
#  ['Grapes', 'Wrath', 'John', 'Steinbeck', 'Centennial', 'Edition', '19022002'],
#  ['Northern', 'Lights', 'Dark', 'Materials'],
#  ['Prayer', 'Owen', 'Meany'],
#  ['Prophet'],
#  ['Cold', 'Sassy', 'Tree'],
#  ['Tree', 'Grows', 'Brooklyn'],
#  ['Shipping', 'News', 'Novel'],
#  ['Hiding', 'Place'],
#  ['1', 'Ladies', 'Detective', 'Agency', 'Today', 'Show', 'Book', 'Club', '8'],
#  ['Driving',
#   'Mr',
#   'Albert',
#   'Trip',
#   'Across',
#   'America',
#   'Einsteins',
#   'Brain'],
#  ['Shopgirl'],
#  ['Kitchen'],
#  ['Breath', 'Eyes', 'Memory'],
#  ['Walk',
#   'Woods',
#   'Rediscovering',
#   'America',
#   'Appalachian',
#   'Trail',
#   'Official',
#   'Guides',
#   'Appalachian',
#   'Trail'],
#  ['Flanders', 'Panel'],
#  ['Devil',
#   'White',
#   'City',
#   'Murder',
#   'Magic',
#   'Madness',
#   'Fair',
#   'Changed',
#   'America',
#   'Illinois'],
#  ['Chicken',
#   'Soup',
#   'Mothers',
#   'Soul',
#   'Chicken',
#   'Soup',
#   'Soul',
#   'Series',
#   'Paper'],
#  ['Silmarillion'],
#  ['Speak'],
#  ['Songs', 'Ordinary', 'Time', 'Oprahs', 'Book', 'Club', 'Paperback'],
#  ['Stone', 'Monkey', 'Lincoln', 'Rhyme', 'Novel'],
#  ['Saucer'],
#  ['Last', 'Juror'],
#  ['Ill', 'Wind', 'Anna', 'Pigeon', 'Mysteries', 'Paperback'],
#  ['Summer', 'Sisters'],
#  ['Valhalla', 'Rising', 'Dirk', 'Pitt', 'Adventures', 'Paperback'],
#  ['America', 'Jake', 'Grafton', 'Novel', 'Jake', 'Grafton', 'Novel'],
#  ['Nimitz', 'Class'],
#  ['Hitchhikerss', 'Guide', 'Galaxy'],
#  ['Half', 'Asleep', 'Frog', 'Pajamas'],
#  ['Home', 'Mitford', 'Mitford', 'Years'],
#  ['Bel', 'Canto', 'Novel'],
#  ['Around', 'Town'],
#  ['Civil', 'Action'],
#  ['Faking'],
#  ['Mystic', 'Lake'],
#  ['Angel', 'Falls'],
#  ['Fountainhead'],
#  ['Loop'],
#  ['Good', 'Bed'],
#  ['Sight'],
#  ['Sense', 'Sensibility'],
#  ['Vineyard'],
#  ['Big', 'Sleep'],
#  ['Well', 'Meet'],
#  ['Make', 'American', 'Quilt'],
#  ['Ellen', 'Foster'],
#  ['Novel'],
#  ['Sex', 'City'],
#  ['Hours', 'Novel'],
#  ['Resistance', 'Novel'],
#  ['Alias', 'Grace', 'Novel'],
#  ['Almost', 'Paradise'],
#  ['Cold', 'Mountain', 'Novel'],
#  ['Fried', 'Green', 'Tomatoes', 'Whistle', 'Stop', 'Cafe'],
#  ['Bird', 'Bird', 'Instructions', 'Writing', 'Life'],
#  ['Circle', 'Three', 'Novel'],
#  ['Lily', 'White'],
#  ['Cabinet', 'Curiosities'],
#  ['Midnight', 'Runner'],
#  ['Last', 'Time', 'Met', 'Novel'],
#  ['Adventures', 'Huckleberry', 'Finn', 'Dover', 'Thrift', 'Editions'],
#  ['Green', 'Mile'],
#  ['Name', 'Address', 'Withheld', 'Red', 'Dress', 'Ink', 'Paperback'],
#  ['Rachels', 'Holiday'],
#  ['Princess', 'Diaries'],
#  ['Farmers', 'Wife'],
#  ['Wailing', 'Wind'],
#  ['Heartbreaking', 'Work', 'Staggering', 'Genius'],
#  ['Lost', 'Good', 'Book', 'Thursday', 'Next', 'Novels', 'Penguin', 'Books'],
#  ['Bad', 'Heir', 'Day'],
#  ['Apocalipstick'],
#  ['Dress', 'Lodger', 'Ballantine', 'Readers', 'Circle'],
#  ['Valley', 'Dolls', 'Novel'],
#  ['Tunnel', 'Vision', 'VI', 'Warshawski', 'Novels', 'Paperback'],
#  ['Amelia', 'Earhart'],
#  ['Fellowship', 'Ring', 'Lord', 'Rings', 'Part', '1'],
#  ['Eyre', 'Affair', 'Alex', 'Awards', 'Awards'],
#  ['Breakfast', 'Champions'],
#  ['Island', 'Blue', 'Dolphins', 'Laurel', 'Leaf', 'Books'],
#  ['Shadow', 'Hegemon', 'Ender', 'Wiggins', 'Saga', 'Paperback'],
#  ['Night', 'Crew'],
#  ['Blue', 'Nowhere', 'Novel'],
#  ['Sudden', 'Prey'],
#  ['Always', 'Thief'],
#  ['Thief'],
#  ['Deck', 'Halls'],
#  ['Donovan', 'Legacy'],
#  ['Year', 'Provence'],
#  ['Indian', 'Cupboard'],
#  ['Wish'],
#  ['Wind', 'Blows'],
#  ['Hyperion'],
#  ['Witching', 'Hour', 'Lives', 'Mayfair', 'Witches'],
#  ['House', 'Atreides', 'Dune', 'House', 'Trilogy', 'Book', '1'],
#  ['Sparrow'],
#  ['Les', 'Miserables'],
#  ['Say', 'GoodBye', 'Novel'],
#  ['Capture', 'Castle'],
#  ['Expect', 'Youre', 'Expecting', 'Revised', 'Edition'],
#  ['Babyville'],
#  ['Expect', 'First', 'Year'],
#  ['Alchemist', 'Fable', 'Following', 'Dream'],
#  ['Miss', 'Julia', 'Speaks', 'Mind', 'Novel'],
#  ['Big', 'Stone', 'Gap', 'Novel', 'Ballantine', 'Readers', 'Circle'],
#  ['Florabama', 'Ladies', 'Auxiliary', 'Sewing', 'Circle'],
#  ['Back', 'Grownups', 'Novel', 'Ballantine', 'Readers', 'Circle'],
#  ['Cat', 'Played', 'Brahms'],
#  ['Black', 'Notice'],
#  ['Nature', 'Made', 'Boy', 'Raised', 'Girl'],
#  ['Something', 'Bed', 'Drooling'],
#  ['One', 'Money', 'Stephanie', 'Plum', 'Novel'],
#  ['Lord', 'Flies'],
#  ['Blackwood', 'Farm', 'Vampire', 'Chronicles'],
#  ['Atlantis', 'Found'],
#  ['Alienist'],
#  ['Manifold', 'Time', 'Manifold', 'Paperback'],
#  ['Notes', 'Small', 'Island'],
#  ['Red', 'White', 'Blue', 'Novel'],
#  ['Engaging', 'Enemy'],
#  ['Holding', 'Dream', 'Dream', 'Trilogy'],
#  ['Cat', 'Saw', 'Stars', 'Cat', 'Paperback'],
#  ['Pope', 'Joan', 'Ballantine', 'Readers', 'Circle'],
#  ['Thin', 'Air', 'Personal', 'Account', 'Mt', 'Everest', 'Disaster'],
#  ['Wild'],
#  ['Curious',
#   'Incident',
#   'Dog',
#   'NightTime',
#   'Today',
#   'Show',
#   'Book',
#   'Club',
#   '13'],
#  ['Sliver', 'Novel'],
#  ['Law', 'Similars'],
#  ['Walk', 'Two', 'Moons'],
#  ['Im', 'Stranger', 'Notes', 'Returning', 'America', '20', 'Years', 'Away'],
#  ['Cause', 'Death'],
#  ['Poisonwood', 'Bible'],
#  ['Dream'],
#  ['Waiting', 'Exhale'],
#  ['Ultimate', 'Hitchhikers', 'Guide'],
#  ['Vanished', 'Man', 'Lincoln', 'Rhyme', 'Novel'],
#  ['Sullivans', 'Island', 'Lowcountry', 'Tale'],
#  ['Chromosome', '6'],
#  ['Point', 'Origin'],
#  ['Rising', 'Sun'],
#  ['Black', 'Friday'],
#  ['Cradle'],
#  ['1st', 'Die', 'Novel'],
#  ['Cold', 'Case'],
#  ['Cut', 'Long', 'Story', 'Short'],
#  ['Flesh', 'Blood'],
#  ['Legend'],
#  ['L', 'Lawless', 'Kinsey', 'Millhone', 'Mysteries'],
#  ['253'],
#  ['Hocus', 'Pocus'],
#  ['Skinwalkers', 'Joe', 'LeaphornJim', 'Chee', 'Novels'],
#  ['Sis', 'Boom', 'Bah'],
#  ['Switcheroo', 'Novel'],
#  ['Everythings', 'Eventual', '14', 'Dark', 'Tales'],
#  ['Lost', 'Girls'],
#  ['Cup', 'Tea', 'Ballantine', 'Readers', 'Circle'],
#  ['Leaving', 'Home'],
#  ['Passion', 'Artemisia'],
#  ['Earth'],
#  ['Lost', 'World'],
#  ['Giver', 'Readers', 'Circle'],
#  ['Instance', 'Fingerpost'],
#  ['Shelters', 'Stone', 'Earths', 'Children', 'Series', '5'],
#  ['Reversible', 'Errors', 'Novel'],
#  ['Man', 'Mistook', 'Wife', 'Hat', 'Clinical', 'Tales'],
#  ['Room', 'Ones'],
#  ['White', 'Oleander', 'Novel'],
#  ['Private', 'Eyes', 'Alex', 'Delaware', 'Novels', 'Paperback'],
#  ['City', 'Bones'],
#  ['Lucky'],
#  ['CATS', 'EYE'],
#  ['Handmaids', 'Tale'],
#  ['Girl', 'Loved', 'Tom', 'Gordon', 'Novel'],
#  ['Murder', 'Book'],
#  ['Captain',
#   'Underpants',
#   'Attack',
#   'Talking',
#   'Toilets',
#   'Another',
#   'Epic',
#   'Novel',
#   'Captain',
#   'Underpants',
#   'Paper'],
#  ['Das', 'Parfum', 'Die', 'Geschichte', 'Eines', 'Morders'],
#  ['Body', 'Lies'],
#  ['Amazonia'],
#  ['Standing', 'Rainbow', 'Novel'],
#  ['Raven', 'Orphans'],
#  ['EVERYTHING', 'EVER', 'WANTED'],
#  ['Sound', 'Fury', 'Vintage', 'International'],
#  ['Cat', 'Could', 'Read', 'Backwards'],
#  ['Cat', 'Knew', 'Shakespeare'],
#  ['Cat', 'Wasnt'],
#  ['Alias', 'Grace'],
#  ['Ishmael', 'Adventure', 'Mind', 'Spirit'],
#  ['Baudolino'],
#  ['Lightning'],
#  ['Hearts', 'Atlantis'],
#  ['Mercy'],
#  ['Acceptable', 'Time'],
#  ['Eyes', 'Dragon'],
#  ['Dive',
#   'Clausens',
#   'Pier',
#   'Novel',
#   'Vintage',
#   'Contemporaries',
#   'Paperback'],
#  ['Simple', 'Truth'],
#  ['Enchantment'],
#  ['Sister', 'Heart'],
#  ['Cryptonomicon'],
#  ['Tracks', 'RI'],
#  ['Love', 'Medicine'],
#  ['Last', 'Man', 'Standing'],
#  ['Country', 'Novel'],
#  ['Evensong', 'Ballantine', 'Readers', 'Circle'],
#  ['Maze'],
#  ['World'],
#  ['Canaan', 'Mitford', 'Years'],
#  ['High', 'Green', 'Hills', 'Mitford', 'Years'],
#  ['Light', 'Window', 'Mitford', 'Years'],
#  ['1984'],
#  ['Mama', 'Day', 'Vintage', 'Contemporaries'],
#  ['Reviving',
#   'Ophelia',
#   'Saving',
#   'Selves',
#   'Adolescent',
#   'Girls',
#   'Ballantine',
#   'Readers',
#   'Circle'],
#  ['Night', 'Holiday', 'Classics'],
#  ['Place', 'Called', 'Freedom'],
#  ['Mists', 'Avalon'],
#  ['Hot', 'Six', 'Stephanie', 'Plum', 'Novel', 'Stephanie', 'Plum', 'Novel'],
#  ['Jemima', 'J', 'Novel', 'Ugly', 'Ducklings', 'Swans'],
#  ['Perfect',
#   'Neighbor',
#   'Macgregors',
#   'Macgregors',
#   'Special',
#   'Edition',
#   'Series',
#   '1232'],
#  ['Harry', 'Potter', 'Sorcerers', 'Stone', 'Harry', 'Potter', 'Paperback'],
#  ['Sea', 'Glass', 'Novel'],
#  ['Side', 'Mountain'],
#  ['American', 'Pastoral'],
#  ['Year', 'Provence'],
#  ['Portrait', 'Sepia', 'Novel'],
#  ['Daughter', 'Fortune', 'Novel'],
#  ['Chicken',
#   'Soup',
#   'College',
#   'Soul',
#   'Inspiring',
#   'Humorous',
#   'Stories',
#   'College',
#   'Students',
#   'Chicken',
#   'Soup',
#   'Soul'],
#  ['Seven', 'Habits', 'Highly', 'Effective', 'People'],
#  ['Skinny', 'Legs'],
#  ['Dangerous', 'Know'],
#  ['Politika', 'Tom', 'Clancys', 'Power', 'Plays', 'Paperback'],
#  ['Blood', 'Orchid'],
#  ['Fahrenheit', '451'],
#  ['Enders', 'Game', 'Ender', 'Wiggins', 'Saga', 'Paperback'],
#  ['House', 'Harkonnen', 'Dune', 'House', 'Trilogy', 'Book', '2'],
#  ['Chapterhouse', 'Dune', 'Dune', 'Chronicles', 'Book', '6'],
#  ['God', 'Emperor', 'Dune', 'Dune', 'Chronicles', 'Book', '4'],
#  ['Children', 'Dune', 'Dune', 'Chronicles', 'Book', '3'],
#  ['Blackwood', 'Farm', 'Rice', 'Anne', 'Vampire', 'Chronicles'],
#  ['Andromeda', 'Strain'],
#  ['Loves', 'Music', 'Loves', 'Dance'],
#  ['Killer', 'Angels'],
#  ['Dolores', 'Claiborne'],
#  ['Pandora', 'New', 'Tales', 'Vampires', 'New', 'Tales', 'Vampires'],
#  ['Hero', 'Crown'],
#  ['Lies',
#   'Teacher',
#   'Told',
#   'Everything',
#   'American',
#   'History',
#   'Textbook',
#   'Got',
#   'Wrong'],
#  ['Lord', 'Chaos', 'Wheel', 'Time', 'Book', '6'],
#  ['Fires', 'Heaven', 'Wheel', 'Time', 'Book', '5'],
#  ['Shadow', 'Rising', 'Wheel', 'Time', 'Book', '4'],
#  ['Eye', 'World', 'Wheel', 'Time', 'Book', '1'],
#  ['Growing', 'Pains', 'Adrian', 'Mole'],
#  ['Clear', 'Present', 'Danger', 'Jack', 'Ryan', 'Novels'],
#  ['Tuesdays',
#   'Morrie',
#   'Old',
#   'Man',
#   'Young',
#   'Man',
#   'Lifes',
#   'Greatest',
#   'Lesson'],
#  ['Tell', 'One'],
#  ['Eats', 'Shoots', 'Leaves', 'Zero', 'Tolerance', 'Approach', 'Punctuation'],
#  ['Walk', 'Woods', 'Rediscovering', 'America', 'Appalachian', 'Trail'],
#  ['Waiting', 'Vintage', 'International'],
#  ['Flowers', 'Algernon', 'Bantam', 'Classic'],
#  ['Secret', 'Diary', 'Adrian', 'Mole', 'Aged', '13', '34'],
#  ['Sum', 'Fears', 'Jack', 'Ryan', 'Novels'],
#  ['Girls', 'Weird', 'Novel'],
#  ['Murder',
#   'Orient',
#   'Express',
#   'Hercule',
#   'Poirot',
#   'Mysteries',
#   'Paperback'],
#  ['WLD', 'ACCORDNG', 'GARP'],
#  ['Icebound'],
#  ['Mystic', 'River'],
#  ['Pay', 'Forward', 'Novel'],
#  ['Cold', 'Heart', 'Alex', 'Delaware', 'Novel'],
#  ['Jester'],
#  ['Witnesses', 'Novel'],
#  ['Roadwork'],
#  ['Watermelon'],
#  ['Sick', 'Puppy'],
#  ['Prey'],
#  ['Fear', 'Nothing'],
#  ['Key', 'Rebecca'],
#  ['Shadows', 'Steel'],
#  ['J', 'Judgment'],
#  ['Void', 'Moon'],
#  ['Last', 'Coyote', 'Last', 'Coyote'],
#  ['Alibi', 'Kinsey', 'Millhone', 'Mysteries', 'Paperback'],
#  ['Sphere'],
#  ['Still', 'Life', 'Woodpecker'],
#  ['Pelican', 'Brief'],
#  ['Bridge', 'Across', 'Forever'],
#  ['One'],
#  ['Bridget', 'Jones', 'Edge', 'Reason'],
#  ['Dont', 'Stand', 'Close', 'Naked', 'Man'],
#  ['Babyhood'],
#  ['Westing', 'Game', 'Speak'],
#  ['Interview', 'Vampire'],
#  ['Queen', 'Damned', 'Vampire', 'Chronicles', 'Paperback'],
#  ['Lord', 'God', 'Made'],
#  ['Outlaw'],
#  ['Book', 'Ruth', 'Oprahs', 'Book', 'Club', 'Paperback'],
#  ['Good'],
#  ['Succulent', 'Wild', 'Woman'],
#  ['Color', 'Purple'],
#  ['Mirror', 'Image'],
#  ['Notebook'],
#  ['Carnal', 'Innocence'],
#  ['Fulfillment'],
#  ['Bloodstream'],
#  ['List', '7'],
#  ['Veronika', 'Decides', 'Die'],
#  ['Beautiful',
#   'Mind',
#   'Life',
#   'Mathematical',
#   'Genius',
#   'Nobel',
#   'Laureate',
#   'John',
#   'Nash'],
#  ['Belong'],
#  ['Reading', 'Lolita', 'Tehran', 'Memoir', 'Books'],
#  ['Peace', 'Like', 'River'],
#  ['Embraced', 'Light'],
#  ['Cry', 'Wolf'],
#  ['Magic', 'Kingdom', 'Sale', 'Sold', 'Magic', 'Kingdom', 'Landover'],
#  ['Black', 'Unicorn', 'Magic', 'Kingdom', 'Landover', 'Novel'],
#  ['Invasion', 'Animorphs', '1'],
#  ['Talk', 'Kids', 'Listen', 'Listen', 'Kids', 'Talk'],
#  ['50', 'Simple', 'Things', 'Save', 'Earth'],
#  ['FOREVER', 'Novel', 'Good', 'Evil', 'Love', 'Hope'],
#  ['Cat', 'Went', 'Creek'],
#  ['Cat', 'Sang', 'Birds', 'Cat', 'Paperback'],
#  ['Visitor', 'Animorphs', '2'],
#  ['Encounter', 'Animorphs', '3'],
#  ['Montana', 'Sky'],
#  ['Scrooge', 'Wore', 'Spurs'],
#  ['See', 'Jane', 'Score', 'Avon', 'Romance'],
#  ['Love', 'Proper', 'Husband', 'Avon', 'Historical', 'Romance'],
#  ['Breathing', 'Room', 'Avon', 'Romance'],
#  ['River', 'Road', 'Ross', 'Joann', 'Callahan', 'Brothers', 'Trilogy', '2'],
#  ['Heart', 'Warrior'],
#  ['Lady', 'Sophias', 'Lover'],
#  ['Silent', 'Honor'],
#  ['Cat', 'Blew', 'Whistle'],
#  ['Diary', 'Mad', 'Bride', 'Summer', 'Display', 'Opportunity'],
#  ['Cry', 'Beloved', 'Country', 'Oprahs', 'Book', 'Club'],
#  ['Carolina', 'Moon'],
#  ['Standing', 'Rainbow'],
#  ['East', 'Eden', 'Oprahs', 'Book', 'Club'],
#  ['Three', 'Fates'],
#  ['Pay', 'Forward'],
#  ['XFiles', 'Ground', 'Zero'],
#  ['Earth', 'Oprahs', 'Book', 'Club'],
#  ['Bastard', 'Carolina'],
#  ['Face', 'Fire', 'Three', 'Sisters', 'Island', 'Trilogy'],
#  ['Hobbit', 'Back'],
#  ['Druids'],
#  ['Count', 'Zero', 'Ace', 'Science', 'Fiction'],
#  ['Difference', 'Engine'],
#  ['Stupid', 'White', 'Men', 'Sorry', 'Excuses', 'State', 'Nation'],
#  ['Harry', 'Potter', 'Sorcerers', 'Stone', 'Book', '1'],
#  ['Dude', 'Wheres', 'Country'],
#  ['Summon', 'Keeper'],
#  ['Bee', 'Season', 'Novel'],
#  ['Homecoming'],
#  ['Phantoms'],
#  ['Jitterbug', 'Perfume'],
#  ['ANGELAS', 'ASHES'],
#  ['Violets', 'Blue'],
#  ['Dogs', 'Babel', 'Today', 'Show', 'Book', 'Club', '12'],
#  ['Tar', 'Baby'],
#  ['Contagion'],
#  ['Der', 'Vorleser'],
#  ['Tale', 'Body', 'Thief', 'Vampire', 'Chronicles', 'Paperback'],
#  ['Startide', 'Rising', 'Uplift', 'Saga', 'Book', '2'],
#  ['City', 'Golden', 'Shadow', 'Otherland', 'Volume', '1'],
#  ['Night', 'Chills'],
#  ['Cruel', 'Unusual', 'Kay', 'Scarpetta', 'Mysteries', 'Paperback'],
#  ['Misery'],
#  ['Eyre', 'Affair', 'Novel'],
#  ['Lying', 'Awake'],
#  ['Mariette', 'Ecstasy'],
#  ['Body', 'Farm'],
#  ['Mortal', 'Fear'],
#  ['Gold', 'Coast'],
#  ['Light', 'Moon'],
#  ['Watchers'],
#  ['Intensity'],
#  ['Dark', 'Rivers', 'Heart'],
#  ['Mr', 'Murder'],
#  ['Hours', 'Novel'],
#  ['Day', 'Late', 'Dollar', 'Short'],
#  ['Professor', 'Madman'],
#  ['Flesh', 'Tones', 'Novel'],
#  ['Bonesetters', 'Daughter'],
#  ['Mistress', 'Spices'],
#  ['Hundred', 'Secret', 'Senses'],
#  ['Midwives', 'Novel'],
#  ['Cold', 'Blood', 'Vintage', 'International'],
#  ['Song', 'Solomon', 'Oprahs', 'Book', 'Club', 'Paperback'],
#  ['Voyage', 'Dawn', 'Treader'],
#  ['Prometheus', 'Deception'],
#  ['Great', 'Hunt', 'Wheel', 'Time', 'Book', '2'],
#  ['Atlas', 'Shrugged'],
#  ['Good', 'Earth', 'Enriched', 'Classics'],
#  ['Number', 'Stars', 'Yearling', 'Newbery'],
#  ['Know', 'Much', 'True'],
#  ['Hinds', 'Feet', 'High', 'Places'],
#  ['Nines', 'Stephanie', 'Plum', 'Novel'],
#  ['Carrie', 'Pilby', 'Red', 'Dress', 'Ink', 'Paperback'],
#  ['Free'],
#  ['Venezianisches', 'Finale', 'Commissario', 'Brunettis', 'erster', 'Fall'],
#  ['Die', 'fÃÂ¼nfte', 'Frau'],
#  ['Behind', 'Scenes', 'Museum', 'Novel'],
#  ['Hill', 'Towns'],
#  ['Witness'],
#  ['Dont',
#   'Sweat',
#   'Small',
#   'Stuff',
#   'Small',
#   'Stuff',
#   'Simple',
#   'Ways',
#   'Keep',
#   'Little',
#   'Things',
#   'Taking',
#   'Life',
#   'Dont',
#   'Sweat',
#   'Small',
#   'Stuff',
#   'Series'],
#  ['Monster', 'Novel', 'Alex', 'Delaware', 'Novels', 'Paperback'],
#  ['Moon',
#   'Music',
#   'Peter',
#   'Decker',
#   'Rina',
#   'Lazarus',
#   'Novels',
#   'Paperback'],
#  ['Carnivorous', 'Carnival', 'Series', 'Unfortunate', 'Events', 'Book', '9'],
#  ['Call', 'Wild'],
#  ['Term', 'Limits'],
#  ['Girl', 'Interrupted'],
#  ['Whispers'],
#  ['Four', 'Score', 'Stephanie', 'Plum', 'Novel'],
#  ['Rising', 'Tides'],
#  ['Born', 'Fire'],
#  ['Watership'],
#  ['Bellwether'],
#  ['High', 'Five', 'Stephanie', 'Plum', 'Novel'],
#  ['Galileos', 'Daughter', 'Historical', 'Memoir', 'Science', 'Faith', 'Love'],
#  ['Five', 'Quarters', 'Orange'],
#  ['Like',
#   'Water',
#   'Chocolate',
#   'Novel',
#   'Monthly',
#   'Installments',
#   'Recipes',
#   'Romances',
#   'Home',
#   'Remedies'],
#  ['Partner', 'Crime'],
#  ['Red', 'Badge', 'Courage', 'Bantam', 'Classics'],
#  ['Girl', 'Pearl', 'Earring'],
#  ['Das', 'Superwieb'],
#  ['Follow', 'River'],
#  ['Personal', 'History'],
#  ['Unless', 'Novel'],
#  ['Dive', 'Clausens', 'Pier', 'Alex', 'Awards'],
#  ['Child', 'Called', 'One', 'Childs', 'Courage', 'Survive'],
#  ['Monster', 'Blood', 'Goosebumps', '3'],
#  ['Stay', 'Basement', 'Goosebumps', '2'],
#  ['Mossflower', 'Redwall', 'Book', '2'],
#  ['Final', 'Target'],
#  ['Warning', 'Signs'],
#  ['Dragons', 'Autumn', 'Twilight', 'Dragonlance', 'Chronicles', 'Vol', '1'],
#  ['Bookends', 'Novel'],
#  ['Map', 'World'],
#  ['Siddhartha'],
#  ['Julie', 'Wolves', 'Julie', 'Wolves'],
#  ['Tribulation',
#   'Force',
#   'Continuing',
#   'Drama',
#   'Left',
#   'Behind',
#   'Left',
#   'Behind',
#   '2'],
#  ['Klone', 'HighTech', 'Love', 'Story'],
#  ['Runaway', 'Jury'],
#  ['Without', 'Remorse'],
#  ['Bear', 'Dragon', 'Jack', 'Ryan', 'Novels'],
#  ['Woman', 'Next', 'Door'],
#  ['Divine', 'Secrets', 'YaYa', 'Sisterhood', 'Novel'],
#  ['Bookshop', 'Novel'],
#  ['Naked', 'Lunch'],
#  ['Color', 'Magic'],
#  ['Illusions', 'Adventures', 'Reluctant', 'Messiah'],
#  ['Hobbit', 'Enchanting', 'Prelude', 'Lord', 'Rings'],
#  ['Stand', 'Complete', 'Uncut', 'Edition'],
#  ['Russendisko'],
#  ['Hunde', 'von', 'Riga'],
#  ['Vanishings', 'Left', 'Behind', 'Kids', '1'],
#  ['Tales', 'Fourth', 'Grade', 'Nothing'],
#  ['Plains', 'Passage', 'Earths', 'Children'],
#  ['Chicken', 'Soup', 'Teenage', 'Soul', 'Chicken', 'Soup', 'Soul'],
#  ['Dress', 'Family', 'Corduroy', 'Denim'],
#  ['Cats', 'Cradle'],
#  ['Robot'],
#  ['Chicken',
#   'Soup',
#   'Teenage',
#   'Soul',
#   'II',
#   'Chicken',
#   'Soup',
#   'Soul',
#   'Series'],
#  ['Elvis', 'Jesus', 'CocaCola', 'Kinky', 'Friedman', 'Novels', 'Paperback'],
#  ['Ship', 'Searched'],
#  ['Devils', 'Waltz', 'Alex', 'Delaware', 'Novels', 'Paperback'],
#  ['Clinic', 'Alex', 'Delaware', 'Novels', 'Paperback'],
#  ['Hornets', 'Nest'],
#  ['Dragon', 'Reborn', 'Wheel', 'Time', 'Book', '3'],
#  ['Contact'],
#  ['Temple', 'Familiar'],
#  ['Dinner', 'Homesick', 'Restaurant'],
#  ['Farewell', 'Arms', 'Scribner', 'Classic'],
#  ['Harry', 'Potter', 'Chamber', 'Secrets', 'Book', '2'],
#  ['Mama', 'Makes', 'Mind', 'Dangers', 'Southern', 'Living'],
#  ['Calculating', 'God'],
#  ['Jane', 'Eyre', 'Bantam', 'Classics'],
#  ['Cat', 'Talked', 'Ghosts'],
#  ['Curious', 'Incident', 'Dog', 'NightTime', 'Vintage', 'Contemporaries'],
#  ['Member', 'Wedding'],
#  ['Corrections', 'Oprah', 'Edition'],
#  ['Sula'],
#  ['Love', 'Time', 'Cholera', 'Penguin', 'Great', 'Books', '20th', 'Century'],
#  ['Microserfs'],
#  ['ACCORDION', 'CRIMES'],
#  ['Androids', 'Dream', 'Electric', 'Sheep'],
#  ['Lucky'],
#  ['Favorite', 'Bride'],
#  ['Booked', 'Die', 'Cliff', 'Janeway', 'Novels', 'Paperback'],
#  ['Cats', 'Eye'],
#  ['Balzac', 'Little', 'Chinese', 'Seamstress'],
#  ['Ashes', 'Ashes'],
#  ['Run'],
#  ['Billy', 'Straight', 'Novel'],
#  ['Professor',
#   'Madman',
#   'Tale',
#   'Murder',
#   'Insanity',
#   'Making',
#   'Oxford',
#   'English',
#   'Dictionary'],
#  ['ONE',
#   'DAY',
#   'SOUL',
#   'OPENED',
#   '40',
#   'DAYS',
#   '40',
#   'NIGHTS',
#   'TOWARD',
#   'SPIRITUAL',
#   'STRENGTH',
#   'PERSONAL',
#   'GROWTH'],
#  ['Sergei', 'Love', 'Story'],
#  ['Insomnia'],
#  ['MOONLIGHT', 'BECOMES'],
#  ['Stillwatch'],
#  ['Really', 'Loved'],
#  ['ROAD',
#   'LESS',
#   'TRAVELED',
#   'New',
#   'Psychology',
#   'Love',
#   'Traditional',
#   'Values',
#   'Spritual',
#   'Growth',
#   'Touchstone',
#   'Books',
#   'Paperback'],
#  ['Midnight'],
#  ['Golden',
#   'Mean',
#   'Extraordinary',
#   'Correspondence',
#   'Griffin',
#   'Sabine',
#   'Concludes'],
#  ['Mayday'],
#  ['Disgrace'],
#  ['Heart', 'Sea', 'Tragedy', 'Whaleship', 'Essex'],
#  ['Pandora', 'New', 'Tales', 'Vampires'],
#  ['FLOOD', 'TIDE'],
#  ['Thief', 'Time', 'Joe', 'LeaphornJim', 'Chee', 'Novels'],
#  ['Slammerkin'],
#  ['Plains', 'Passage', 'Earths', 'Children', 'Paperback'],
#  ['First', 'Counsel'],
#  ['Dead', 'Run'],
#  ['Kushiels', 'Dart'],
#  ['Daughter', 'Blood', 'Black', 'Jewels', 'Trilogy'],
#  ['Remains', 'Day'],
#  ['Cane', 'River'],
#  ['AGE', 'INNOCENCE', 'MOVIE', 'TIEIN'],
#  ['Surgeon'],
#  ['Church', 'Dead', 'Girls'],
#  ['Last', 'Innocent', 'Man'],
#  ['Basket', 'Case'],
#  ['Holes'],
#  ['Presumed', 'Innocent'],
#  ['Poet'],
#  ['Midnight', 'Club'],
#  ['Anne', 'Avonlea', 'Anne', 'Green', 'Gables', 'Novels', 'Paperback'],
#  ['Indian', 'Cupboard', 'rack', 'Indian', 'Cupboard'],
#  ['UhOh', 'Observations', 'Sides', 'Refrigerator', 'Door'],
#  ['Fire', 'Lay'],
#  ['Really',
#   'Need',
#   'Know',
#   'Learned',
#   'Kindergarten',
#   'Uncommon',
#   'Thoughts',
#   'Common',
#   'Things'],
#  ['Pleading', 'Guilty'],
#  ['Politically',
#   'Correct',
#   'Bedtime',
#   'Stories',
#   'Modern',
#   'Tales',
#   'Life',
#   'Times'],
#  ['4', 'Blondes'],
#  ['Night'],
#  ['Seduction', 'Death'],
#  ['Winters', 'Tale'],
#  ['Childhoods', 'End'],
#  ['Cat', 'Hat'],
#  ['Shipping', 'News'],
#  ['STONES', 'RIVER'],
#  ['Guns', 'Germs', 'Steel', 'Fates', 'Human', 'Societies'],
#  ['Hearts', 'Atlantis', 'New', 'Fiction'],
#  ['Black', 'House'],
#  ['Falling', 'Angels'],
#  ['Holidays', 'Ice', 'Stories'],
#  ['Wicca', 'Guide', 'Solitary', 'Practitioner'],
#  ['Midnight', 'Champagne', 'Novel', 'Mysteries', 'Horror'],
#  ['Women',
#   'Brewster',
#   'Place',
#   'Penguin',
#   'Contemporary',
#   'American',
#   'Fiction',
#   'Series'],
#  ['Valley', 'Horses'],
#  ['Clan', 'Cave', 'Bear', 'novel'],
#  ['Desperation'],
#  ['Harry', 'Potter', 'Prisoner', 'Azkaban', 'Book', '3'],
#  ['Deadly', 'Decisions'],
#  ['Changes'],
#  ['Charlottes', 'Web', 'Trophy', 'Newbery'],
#  ['Jedi', 'Search', 'Star', 'Wars', 'Jedi', 'Academy', 'Trilogy', 'Vol', '1'],
#  ['Battlefield', 'Earth', 'Saga', 'Year', '3000'],
#  ['Primary', 'Colors', 'Novel', 'Politics'],
#  ['Lottery', 'Winner', 'Alvirah', 'Willy', 'Stories'],
#  ['Wild', 'Justice'],
#  ['Midnight', 'Voices'],
#  ['Gift'],
#  ['Send', 'Flowers'],
#  ['Bend', 'Road'],
#  ['Dry', 'Memoir'],
#  ['Yukon', 'Ho'],
#  ['Calvin', 'Hobbes', 'Tenth', 'Anniversary', 'Book'],
#  ['Ella', 'Enchanted', 'Trophy', 'Newbery'],
#  ['Wizard', 'Earthsea', 'Earthsea', 'Trilogy', 'Book', '1'],
#  ...]

# %%
CV_Matrix = CountVectorizer(analyzer=convert_to_list).fit_transform(books)

# %%
print(CV_Matrix.shape)
print(CV_Matrix.nnz)
# Out:
# (3859, 4563)
# 12643

# %%
TfIdf_Matrix = TfidfTransformer().fit_transform(CV_Matrix)

# %%
Desc_sim = linear_kernel(TfIdf_Matrix,TfIdf_Matrix)

# %%
df = pd.DataFrame(books,columns=['title'])
indices = pd.Series(df.index, index=df['title'].apply(lambda x: x.lower()))
indices.head(3)
# Out:
# title
# the kitchen god's wife                  0
# the testament                           1
# beloved (plume contemporary fiction)    2
# dtype: int64

# %%
def book_recomendation(title):
    title = title.lower()
    idx = indices[title]
    
    # Get the pairwsie similarity scores of all books with that book
    sim_scores = list(enumerate(Desc_sim[idx]))

    # Sort the books based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar books
    sim_scores = sim_scores[1:10]

    # Get the book indices
    book_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar books
    return df['title'].iloc[book_indices]

# %%
book_recomendation('Golden Cup')
# Out:
# 1446                                        Golden Orange
# 588             A Cup of Tea (Ballantine Reader's Circle)
# 2082    Dragonwings : Golden Mountain Chronicles: 1903...
# 224       The Golden Compass (His Dark Materials, Book 1)
# 792           City of Golden Shadow (Otherland, Volume 1)
# 3445    The Illuminatus Trilogy: The Eye in the Pyrami...
# 932     The Golden Mean: In Which the Extraordinary Co...
# 2916    The End Of The Dream The Golden Boy Who Never ...
# 0                                  The Kitchen God's Wife
# Name: title, dtype: object

# %%
book_recomendation('Golden Cup').tolist()
# Out:
# ['Golden Orange',
#  "A Cup of Tea (Ballantine Reader's Circle)",
#  'Dragonwings : Golden Mountain Chronicles: 1903 (Golden Mountain Chronicles)',
#  'The Golden Compass (His Dark Materials, Book 1)',
#  'City of Golden Shadow (Otherland, Volume 1)',
#  'The Illuminatus Trilogy: The Eye in the Pyramid, the Golden Apple & Leviathan',
#  'The Golden Mean: In Which the Extraordinary Correspondence of Griffin & Sabine Concludes',
#  'The End Of The Dream The Golden Boy Who Never Grew Up : Ann Rules Crime Files Volume 5',
#  "The Kitchen God's Wife"]

# %% [markdown]
# ### Interfaz

# %%
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output# Load Data

# %%
app = JupyterDash(__name__)
app.layout = html.Div([
    html.H1("Proyecto Final IA: Grupo 3"),
    html.H2("Sistema de recomendación de libros"),
    dcc.Input(
            id="book",
            type="text",
            placeholder="Input the book tittle",
            style={"width": "50%"},
        ),
    html.Br(),
    html.Br(),
    html.H3("KNN:"),
    html.Div(id="outputknn"),
    html.Br(),
    html.Br(),
    html.H3("TF-IDF:"),
    html.Div(id="outputtdfif"),

])

@app.callback(
    Output("outputknn", "children"),
    Output("outputtdfif", "children"),
    Input("book", "value"),
)
def update_output(book):
    if book in listaDeTitulos:
        recknn = recoForInteface(book)
        rectdfif = book_recomendation(book).tolist()
        return u'books recommended for {}: {}'.format(recknn[0],recknn[1:]),u'books recommended for {}: {}'.format(book,rectdfif)
    else:
        rec = "book not found"
        return rec,rec

# %%
app.run_server(mode='external')
# Out:
# Dash app running on http://127.0.0.1:8050/

# %% [markdown]
# ### Deploy
